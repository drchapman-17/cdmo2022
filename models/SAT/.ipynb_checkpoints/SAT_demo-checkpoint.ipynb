# %% [markdown]
# # VLSI - SAT Model
#
# #### Definition of the problem
# **Input**: A set *R = {r1, . . . , rn}* of *n* rectangles. Each rectangle
# *ri ∈ R* has a width *w_i* and a height *h_i* *(w_i, h_i ∈ N)*. A Strip of
# width *W ∈ N*.
#
# **Constraints**: Each rectangle cannot overlap with the others
# and the edges of the strip and must be parallel to the horizontal
# and the vertical axis.
#
# **Question**: What is the minimum height such that the set of
# rectangles can be packed in the given strip?

# %%
# !pip3 install z3-solver
# Out:
# Requirement already satisfied: z3-solver in c:\users\antonio\anaconda3\envs\comb\lib\site-packages (4.8.15.0)
# Impossibile trovare il percorso specificato.

# %%
import os,sys,inspect,getopt
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import time
from z3 import *
import math

currentdir = os.path.dirname(os.path.realpath("__file__"))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir) 
import utils

# %% [markdown]
# ### Useful functions

# %%
def large_rectangles(w_i, w_j, h_i, h_j, W, H):
    if w_i + w_j <= W and h_i + h_j <= H:
        return ""
    elif w_i + w_j > W and h_i + h_j <= H:
        return "W"
    elif w_i + w_j <= W and h_i + h_j > H:
        return "H"

def same_rectangles(w1,w2,h1,h2):
    if w1 == w2 and h1 == h2:
        return True
    else:
        return False

def largest_rectangle(idx, max_idx):
    if idx == max_idx:
        return True
    else:
        return False
    
def no_overlap(W, H, widths, heights, i, j, flip, px, py, lr, ud):            
    dim1,dim2=(widths[i],heights[i]) if not flip else (heights[i],widths[i])
    cts=[]
    
    if lr:
        # lr(r_i,r_j)-> x_j > w_i
        cts.append(Or(
                Not(lr[i][j]),
                Not(px[j][dim1-1]),
            )) 

        for e in range(0,W-dim1):
            cts.append(Or(
                Not(lr[i][j]),
                px[i][e],
                Not(px[j][e+dim1]),
            ))

    if ud:
        # ud(r_i,r_j)-> y_j > h_i
        cts.append(Or(
                Not(ud[i][j]),
                Not(py[j][dim2-1])
            ))

        for f in range(0,H-dim2):
            cts.append(Or(
                Not(ud[i][j]),
                py[i][f],
                Not(py[j][f+dim2])
            ))

    return cts

def getCoords(vars_dict, W, H, n, widths, heights, rot = False):
    x_sol = []
    y_sol = [] 
    w=[]
    h=[]
                
    for i in range(n):
        if rot:
            if vars_dict[f"f{i+1}"]:  
                w.append(heights[i])
                h.append(widths[i])
            else:
                w.append(widths[i])
                h.append(heights[i])
                
        x = 0
        while x < W:
            try:
                if vars_dict[f"px{i+1}_{x}"]:                
                    x_sol.append(x)
                    break
            except:
                pass
            x += 1
        y = 0
        
        while y < H:
            try:
                if vars_dict[f"py{i+1}_{y}"]:                
                    y_sol.append(y)
                    break
            except:
                pass
            y += 1
        
    return x_sol, y_sol, w, h

# %% [markdown]
# ### Model - Order Encoding
#
# [1] https://web.telegram.org/cd003ba1-9c37-41f3-9be7-dceeb848b5e2
#
# [2] https://sourceforge.net/p/potassco/mailman/attachment/1323943585.4102.431.camel@white.sevalidation.com/1/

# %%
'''
 # SEARCH SPACE REDUCTION 
    1. Large Rectangles (LR): 
        Reducing the possibilities for placing large rectangles.
        For each rectangle ri and r j, if wi + w j > W we can not pack
        these rectangles in the horizontal direction. We therefore
        modify non-overlapping constraints.
        This technique is also applicable for the vertical direction.

    2. Same Rectangles (SR):
        For each rectangle ri and r j, if (wi, hi) = (w j, h j) we can 
        fix the positional relation of these rectangles. 
        
    3. Largest Rectangle (LS): 
        Reducing the domain for the largest rectangle.
        With breaking symmetries, we can reduce the domain of
        largest rectangle.

                    D(x_i) = {a ∈ N | 0 ≤ a ≤ floor((W − w_i)/2)}
                    D(y_i) = {a ∈ N | 0 ≤ a ≤ floor((H − h_i)/2)}
'''

def vlsi_sat(instance):
    ''' VARIABLES '''

    n = instance['n']
    W = instance['w']
    widths  = [i[0] for i in instance['dim']]
    heights = [i[1] for i in instance['dim']]
    largest_idx = [w*h for w,h in zip(widths,heights)].index(max([w*h for w,h in\
                                                                        zip(widths,heights)]))   
    tot_area=sum([w*h for w,h in zip(widths,heights)])
    model = None
    
    naiveSolution = utils.computeMostStupidSolution(instance)
    
    if not naiveSolution:
        return None,0.0

    lb = int(math.ceil(tot_area/W))
    ub = naiveSolution[0][1]+1
    
    print("\n>Starting Lower Bound:", lb)
    print(">Starting Upper Bound:", ub)
    
    H = int((lb+ub)/2)
    
    s_time = time.time()
    while (lb < ub):
        s = Solver()
        
        ''' SOLVER WITH 5 MINUTES TIMEOUT'''
        s.set("timeout", int(300-(time.time()-s_time))*1000)
        print(f"\t>Trying H:{H}")
        if (time.time() > s_time + 300):
            break
        
        '''
        ==================================================================
        Let x_i and y_i be integer variables such that the pair (x_i, y_i)
        represents the position of lower left coordinates of the rectangle
        ri in the strip.
        The domains of x_i and y_i are as folbows.
                            D(x_i) = {a ∈ N | 0 ≤ a ≤ W − w_i}
                            D(y_i) = {a ∈ N | 0 ≤ a ≤ H − h_i}
        ==================================================================
        Let r_i, r_j ∈ R(i != j) be two rectangles. We use two
        kinds of propositional variables: lr_i,j and ud_i,j.
        lr_i,j is true if r_i are placed at the left to the r_j.
        ud_i,j is true if r_i are placed at the downward to the r_j.

        ==================================================================
        For each rectangles r_i,r_j (i < j), we have the non-overlapping
        constraints:
                            lr_i,j ∨ lr_j,i ∨ ud_i,j ∨ ud_j,i
                                ¬lr_i,j ∨ (x_i + w_i ≤ x_j)
                                ¬lr_j,i ∨ (x_j + w_j ≤ x_i)
                                ¬ud_i,j ∨ (y_i + h_i ≤ y_j)
                                ¬ud_j,i ∨ (y_j + h_j ≤ y_i)
        The parts between parentheses are encoded into SAT by using order
        encoding.
        '''
        px = [[Bool(f"px{i+1}_{x}") for x in range(W)] for i in range(n)] # x[i][i]: block i has y coordinate <=j
        py = [[Bool(f"py{i+1}_{y}") for y in range(H)] for i in range(n)] # x[i][i]: block i has y coordinate <=j
        lr = [[Bool(f"lr_{i+1}_{j+1}") if j!=i else 0 for j in range(n)] for i in range(n)]
        ud = [[Bool(f"ud_{i+1}_{j+1}") if i!=j else 0 for j in range(n)] for i in range(n)]

        # Exactly One constraint
        for i in range(n): 
            '''
            ==================================================================
            Order encoding is a generalization of the encoding method
            originally used by Crawford and Baker for Job-Shop
            Scheduling problems.
            It uses a different Boolean variable P_x,a representing x ≤ a
            for each integer variable x and integer value a.
            
            For each rectangle r_i, and integer e and f such that
            0 ≤ e ≤ W − wi and 0 ≤ f ≤ H − h_i, we have the 2-literal
            axiom clauses due to order encoding,
                                ¬ px_i,e ∨ px_i,e+1
                                ¬ py_i, f ∨ py_i, f +1
            ==================================================================
            '''            
            if largest_rectangle(i, largest_idx):
                s.add([px[i][e] for e in range(int((W-widths[i])/2),W)]) # block i starts for sure before position W-wi-> x[i][j]=True for all j > W-wi 
                s.add([py[i][f] for f in range(int((H-heights[i])/2),H)]) # same for the y coordinate 
            else:
                s.add([px[i][e] for e in range(W-widths[i],W)]) # block i starts for sure before position W-wi-> x[i][j]=True for all j > W-wi 
                s.add([py[i][f] for f in range(H-heights[i],H)]) # same for the y coordinate 
            
            s.add([Or(Not(px[i][e]),px[i][e+1]) for e in range(W-1)]) #x[i][j] implies x[i][j+1]
            s.add([Or(Not(py[i][f]),py[i][f+1]) for f in range(H-1)]) #y[i][j] implies y[i][j+1]

            for j in range(n):
                '''
                ==================================================================
                For each rectangles i,j (i < j), we have the non-overlapping
                constraints as the 4-literal clauses:
                                lr_i,j ∨ lr_j,i ∨ ud_i,j ∨ ud_j,i 
                                
                For each rectangles i, j (i < j), and integer e and f such that
                0 ≤ e < W − wi and 0 ≤ f < H − h j, we also have the
                non-overlapping constraints as the 3-literal clauses:
                                ¬lr_i,j ∨ px_i,e ∨ ¬px_j,e + w_i
                                ¬lr_j,i ∨ px_j,e ∨ ¬px_i,e + w_j
                                ¬ud_i,j ∨ py_i,f ∨ ¬py_j,f + h_i
                                ¬ud_j,i ∨ py_j,f ∨ ¬py_i,f + h_j
                ==================================================================
                '''
                if i<j:  
                    if large_rectangles(widths[i],widths[j],heights[i],heights[j], W, H) == "":
                        if same_rectangles(widths[i],widths[j],heights[i],heights[j]):
                            s.add(Or(lr[i][j],ud[i][j],ud[j][i]))

                            s.add(
                                *no_overlap(W,H,widths,heights,i,j,False,px,py,lr,ud),
                                *no_overlap(W,H,widths,heights,j,i,False,px,py,False,ud)
                            )

                            s.add(Or(
                                    Not(ud[i][j]),
                                    lr[j][i]
                            ))
                        else:
                            if not largest_rectangle(j, largest_idx):
                                s.add(Or(lr[i][j],lr[j][i],ud[i][j],ud[j][i]))

                                s.add(
                                    *no_overlap(W,H,widths,heights,i,j,False,px,py,lr,ud),
                                    *no_overlap(W,H,widths,heights,j,i,False,px,py,lr,ud)
                                )
                            else:
                                s.add(Or(lr[j][i],ud[i][j],ud[j][i]))

                                s.add(
                                    *no_overlap(W,H,widths,heights,i,j,False,px,py,False,ud),
                                    *no_overlap(W,H,widths,heights,j,i,False,px,py,lr,ud)
                                )
                    elif large_rectangles(widths[i],widths[j],heights[i],heights[j], W, H) == "W":
                        s.add(Or(ud[i][j],ud[j][i]))

                        s.add(
                            *no_overlap(W,H,widths,heights,i,j,False,px,py,False,ud),
                            *no_overlap(W,H,widths,heights,j,i,False,px,py,False,ud)
                        )

                    elif large_rectangles(widths[i],widths[j],heights[i],heights[j], W, H) == "H":
                        if same_rectangles(widths[i],widths[j],heights[i],heights[j]):
                            s.add(lr[i][j])

                            s.add(
                                *no_overlap(W,H,widths,heights,i,j,False,px,py,lr,False)
                            )

                            s.add(Or(
                                    Not(ud[i][j]),
                                    lr[j][i]
                            ))  
                        else:                            
                            s.add(Or(lr[i][j],lr[j][i]))

                            s.add(
                                *no_overlap(W,H,widths,heights,i,j,False,px,py,lr,False),
                                *no_overlap(W,H,widths,heights,j,i,False,px,py,lr,False)
                            )


        if s.check() == sat:
            ub = H
            model = s.model()            
            
            print(f'\t\t>SAT - ub: {ub}, {time.time() - s_time} s')
            
        else:
            lb = H + 1
            if (time.time() - s_time <= 300):
                print(f'\t\t>UNSAT - lb: {lb}, {time.time() - s_time} s')
                
            
        H =  int((lb+ub)/2)
        
        '''
        ==================================================================
        'Bisection Method':
            while lb < ub
                o := (lb + ub)/2;
                resubt := Ψ ∪ {ph_o};
                if resubt is SAT
                    then ub := o;
                    else lb := o + 1;
            end while
        ==================================================================
        '''
    
    e_time = time.time() - s_time
    
    if model == None:
        return None, 0.0
    elif e_time > 300:
        variables = { str(d):model.evaluate(model[d]) for d in model }
        cx,cy,_,_ = getCoords(variables, W, ub, n, widths, heights)

        sol = [[W,ub]]+[[widths[i],heights[i],cx[i]+1,cy[i]+1]\
                    for i in range(min(len(cx),len(cy),len(widths),len(heights)))]
        
        return sol, e_time
    else:
        variables = { str(d):model.evaluate(model[d]) for d in model }
        cx,cy,_,_ = getCoords(variables, W, H, n, widths, heights)
        
        sol=[[W,H]]+[[widths[i],heights[i],cx[i]+1,cy[i]+1]\
                    for i in range(n)]
        
        return sol, e_time

# %%
from_ins = 1
to_ins   = 40

times = []
for ins in range(from_ins, min(to_ins+1,41)):
    print('========================================================================================')

    # Instance
    instance=utils.loadInstance(f"../instances/ins-{ins}.txt")
    print("Instance:",*["{}={}".format(key,val) for key,val in instance.items()])

    # Solving
    sol,e_time = vlsi_sat(instance)
    
    times.append(round(e_time,3))
    if sol == None:
        print(">Unfeasible.")
    
    if e_time > 300:
        # Write to file
        utils.writeSolution('./outputs/out-' + str(ins) + '_non_opt.txt', sol)
        
        # Display solution
        utils.display_solution(sol, title= f'Plate {ins}')

        print(f">Out of time, {round(e_time,3)} s, best height: {sol[0][1]}")
    else:
        # Write to file
        utils.writeSolution('./outputs/out-' + str(ins) + '.txt', sol)

        # Display solution
        utils.display_solution(sol, title= f'Plate {ins}')
        
        # Time
        print(f"Instance[{ins}] solved in {round(e_time,3)} s, height: {sol[0][1]}")
    print('========================================================================================')
    print('\n')

with open('./times_2.txt', 'w+') as f:
    for i in range(from_ins, min(to_ins+1,41)):
            f.write('{}\n'.format(times[i-from_ins]))
# Out:
# ========================================================================================
# Instance: n=4 w=8 dim=[[3, 3], [3, 5], [5, 3], [5, 5]]
#
# >Starting Lower Bound: 8
# >Starting Upper Bound: 9
# 	>Trying H:8
# 		>SAT - ub: 8, 0.13126158714294434 s
# Instance[1] solved in 0.131 s, height: 8
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=5 w=9 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 9]]
#
# >Starting Lower Bound: 9
# >Starting Upper Bound: 10
# 	>Trying H:9
# 		>SAT - ub: 9, 0.0672757625579834 s
# Instance[2] solved in 0.067 s, height: 9
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=6 w=10 dim=[[3, 3], [3, 4], [3, 6], [3, 7], [4, 4], [4, 6]]
#
# >Starting Lower Bound: 10
# >Starting Upper Bound: 14
# 	>Trying H:12
# 		>SAT - ub: 12, 0.11800694465637207 s
# 	>Trying H:11
# 		>SAT - ub: 11, 0.22500300407409668 s
# 	>Trying H:10
# 		>SAT - ub: 10, 0.32260751724243164 s
# Instance[3] solved in 0.324 s, height: 10
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=7 w=11 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [5, 3], [5, 4], [8, 4]]
#
# >Starting Lower Bound: 11
# >Starting Upper Bound: 14
# 	>Trying H:12
# 		>SAT - ub: 12, 0.16299986839294434 s
# 	>Trying H:11
# 		>SAT - ub: 11, 0.3209996223449707 s
# Instance[4] solved in 0.321 s, height: 11
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=8 w=12 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [6, 3]]
#
# >Starting Lower Bound: 12
# >Starting Upper Bound: 14
# 	>Trying H:13
# 		>SAT - ub: 13, 0.22897577285766602 s
# 	>Trying H:12
# 		>SAT - ub: 12, 0.44716620445251465 s
# Instance[5] solved in 0.447 s, height: 12
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=9 w=13 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [4, 3], [4, 4], [7, 6]]
#
# >Starting Lower Bound: 13
# >Starting Upper Bound: 17
# 	>Trying H:15
# 		>SAT - ub: 15, 0.34210634231567383 s
# 	>Trying H:14
# 		>SAT - ub: 14, 0.641624927520752 s
# 	>Trying H:13
# 		>SAT - ub: 13, 0.9395489692687988 s
# Instance[6] solved in 0.94 s, height: 13
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=9 w=14 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [5, 4], [5, 10]]
#
# >Starting Lower Bound: 14
# >Starting Upper Bound: 19
# 	>Trying H:16
# 		>SAT - ub: 16, 0.3713207244873047 s
# 	>Trying H:15
# 		>SAT - ub: 15, 0.696868896484375 s
# 	>Trying H:14
# 		>SAT - ub: 14, 0.9996123313903809 s
# Instance[7] solved in 1.0 s, height: 14
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=10 w=15 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 12], [3, 15], [6, 3]]
#
# >Starting Lower Bound: 15
# >Starting Upper Bound: 16
# 	>Trying H:15
# 		>SAT - ub: 15, 0.4069406986236572 s
# Instance[8] solved in 0.407 s, height: 15
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=10 w=16 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 10], [3, 12], [4, 7], [7, 9]]
#
# >Starting Lower Bound: 16
# >Starting Upper Bound: 21
# 	>Trying H:18
# 		>SAT - ub: 18, 0.45874762535095215 s
# 	>Trying H:17
# 		>SAT - ub: 17, 0.9284055233001709 s
# 	>Trying H:16
# 		>SAT - ub: 16, 1.3727474212646484 s
# Instance[9] solved in 1.373 s, height: 16
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=12 w=17 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [4, 3], [4, 8], [4, 14], [7, 3], [7, 6]]
#
# >Starting Lower Bound: 17
# >Starting Upper Bound: 22
# 	>Trying H:19
# 		>SAT - ub: 19, 0.7589337825775146 s
# 	>Trying H:18
# 		>SAT - ub: 18, 1.4588701725006104 s
# 	>Trying H:17
# 		>SAT - ub: 17, 2.162489652633667 s
# Instance[10] solved in 2.162 s, height: 17
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=16 w=18 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 10], [3, 11], [4, 3], [4, 4], [4, 5], [4, 6], [5, 3], [5, 4], [5, 5], [5, 6]]
#
# >Starting Lower Bound: 18
# >Starting Upper Bound: 22
# 	>Trying H:20
# 		>SAT - ub: 20, 1.4798078536987305 s
# 	>Trying H:19
# 		>SAT - ub: 19, 3.006118059158325 s
# 	>Trying H:18
# 		>SAT - ub: 18, 4.662318229675293 s
# Instance[11] solved in 4.663 s, height: 18
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=14 w=19 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 13], [3, 19], [4, 5], [4, 6], [4, 8]]
#
# >Starting Lower Bound: 19
# >Starting Upper Bound: 24
# 	>Trying H:21
# 		>SAT - ub: 21, 1.1515185832977295 s
# 	>Trying H:20
# 		>SAT - ub: 20, 2.266310214996338 s
# 	>Trying H:19
# 		>SAT - ub: 19, 3.329800605773926 s
# Instance[12] solved in 3.331 s, height: 19
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=14 w=20 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 17], [4, 3], [4, 9], [4, 11], [4, 17]]
#
# >Starting Lower Bound: 20
# >Starting Upper Bound: 25
# 	>Trying H:22
# 		>SAT - ub: 22, 1.1812679767608643 s
# 	>Trying H:21
# 		>SAT - ub: 21, 2.3210604190826416 s
# 	>Trying H:20
# 		>SAT - ub: 20, 3.401552200317383 s
# Instance[13] solved in 3.403 s, height: 20
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=15 w=21 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 14], [3, 18], [4, 4], [4, 6], [4, 11], [5, 6], [5, 15]]
#
# >Starting Lower Bound: 21
# >Starting Upper Bound: 25
# 	>Trying H:23
# 		>SAT - ub: 23, 1.4458847045898438 s
# 	>Trying H:22
# 		>SAT - ub: 22, 2.837423801422119 s
# 	>Trying H:21
# 		>SAT - ub: 21, 4.191281080245972 s
# Instance[14] solved in 4.191 s, height: 21
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=16 w=22 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 13], [3, 14], [3, 22], [4, 3], [4, 19], [6, 4]]
#
# >Starting Lower Bound: 22
# >Starting Upper Bound: 28
# 	>Trying H:25
# 		>SAT - ub: 25, 1.7672207355499268 s
# 	>Trying H:23
# 		>SAT - ub: 23, 3.3380346298217773 s
# 	>Trying H:22
# 		>SAT - ub: 22, 4.879645824432373 s
# Instance[15] solved in 4.88 s, height: 22
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=19 w=23 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 14], [3, 20], [4, 3], [4, 4], [4, 6], [4, 10], [4, 11], [4, 12], [6, 3]]
#
# >Starting Lower Bound: 23
# >Starting Upper Bound: 30
# 	>Trying H:26
# 		>SAT - ub: 26, 2.641223192214966 s
# 	>Trying H:24
# 		>SAT - ub: 24, 5.914947271347046 s
# 	>Trying H:23
# 		>SAT - ub: 23, 9.067199468612671 s
# Instance[16] solved in 9.067 s, height: 23
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=18 w=24 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 12], [3, 14], [3, 18], [3, 24], [4, 3], [4, 4], [4, 5], [4, 12], [5, 8], [5, 16]]
#
# >Starting Lower Bound: 24
# >Starting Upper Bound: 30
# 	>Trying H:27
# 		>SAT - ub: 27, 2.270878553390503 s
# 	>Trying H:25
# 		>SAT - ub: 25, 4.370124101638794 s
# 	>Trying H:24
# 		>SAT - ub: 24, 7.110320568084717 s
# Instance[17] solved in 7.11 s, height: 24
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=19 w=25 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 13], [3, 14], [3, 17], [3, 18], [3, 19], [3, 25], [4, 5], [4, 7], [4, 13], [6, 3]]
#
# >Starting Lower Bound: 25
# >Starting Upper Bound: 31
# 	>Trying H:28
# 		>SAT - ub: 28, 2.5906481742858887 s
# 	>Trying H:26
# 		>SAT - ub: 26, 5.07660698890686 s
# 	>Trying H:25
# 		>SAT - ub: 25, 7.869055509567261 s
# Instance[18] solved in 7.87 s, height: 25
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=22 w=26 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 14], [3, 15], [3, 16], [3, 17], [3, 19], [4, 3], [4, 4], [4, 5], [4, 7], [4, 8], [4, 11], [4, 14]]
#
# >Starting Lower Bound: 26
# >Starting Upper Bound: 33
# 	>Trying H:29
# 		>SAT - ub: 29, 3.7199771404266357 s
# 	>Trying H:27
# 		>SAT - ub: 27, 8.278692722320557 s
# 	>Trying H:26
# 		>SAT - ub: 26, 14.093305110931396 s
# Instance[19] solved in 14.093 s, height: 26
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=21 w=27 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 19], [3, 20], [3, 21], [4, 3], [4, 4], [4, 6], [4, 7], [4, 8], [4, 14], [4, 19], [4, 20]]
#
# >Starting Lower Bound: 27
# >Starting Upper Bound: 31
# 	>Trying H:29
# 		>SAT - ub: 29, 3.7865424156188965 s
# 	>Trying H:28
# 		>SAT - ub: 28, 7.000971555709839 s
# 	>Trying H:27
# 		>SAT - ub: 27, 10.470086812973022 s
# Instance[20] solved in 10.471 s, height: 27
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=22 w=28 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 16], [3, 17], [3, 21], [3, 23], [4, 3], [4, 4], [4, 5], [4, 8], [4, 13], [4, 23], [5, 6], [5, 9], [5, 13]]
#
# >Starting Lower Bound: 28
# >Starting Upper Bound: 35
# 	>Trying H:31
# 		>SAT - ub: 31, 3.8636250495910645 s
# 	>Trying H:29
# 		>SAT - ub: 29, 7.608016729354858 s
# 	>Trying H:28
# 		>SAT - ub: 28, 14.907613754272461 s
# Instance[21] solved in 14.909 s, height: 28
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=24 w=29 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 15], [3, 18], [3, 20], [4, 3], [4, 4], [4, 5], [4, 6], [4, 7], [4, 9], [4, 15], [4, 18], [4, 20], [5, 4], [5, 8], [5, 17]]
#
# >Starting Lower Bound: 29
# >Starting Upper Bound: 39
# 	>Trying H:34
# 		>SAT - ub: 34, 5.173136472702026 s
# 	>Trying H:31
# 		>SAT - ub: 31, 11.528131008148193 s
# 	>Trying H:30
# 		>SAT - ub: 30, 22.496193885803223 s
# 	>Trying H:29
# 		>SAT - ub: 29, 37.29676175117493 s
# Instance[22] solved in 37.297 s, height: 29
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=20 w=30 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 13], [3, 14], [3, 16], [3, 19], [3, 25], [4, 3], [4, 4], [4, 6], [4, 8], [4, 9], [11, 30]]
#
# >Starting Lower Bound: 30
# >Starting Upper Bound: 37
# 	>Trying H:33
# 		>SAT - ub: 33, 3.4105048179626465 s
# 	>Trying H:31
# 		>SAT - ub: 31, 9.685675621032715 s
# 	>Trying H:30
# 		>SAT - ub: 30, 13.029377460479736 s
# Instance[23] solved in 13.029 s, height: 30
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=19 w=31 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 13], [3, 14], [3, 22], [3, 31], [4, 3], [4, 7], [4, 8], [4, 13], [12, 31]]
#
# >Starting Lower Bound: 31
# >Starting Upper Bound: 37
# 	>Trying H:34
# 		>SAT - ub: 34, 3.1687347888946533 s
# 	>Trying H:32
# 		>SAT - ub: 32, 6.25615119934082 s
# 	>Trying H:31
# 		>SAT - ub: 31, 9.318724155426025 s
# Instance[24] solved in 9.319 s, height: 31
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=27 w=32 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 13], [3, 14], [3, 15], [3, 18], [3, 22], [3, 23], [3, 24], [3, 25], [3, 27], [4, 3], [4, 4], [4, 5], [4, 6], [4, 7], [4, 10], [4, 11], [4, 18]]
#
# >Starting Lower Bound: 32
# >Starting Upper Bound: 41
# 	>Trying H:36
# 		>SAT - ub: 36, 7.092465400695801 s
# 	>Trying H:34
# 		>SAT - ub: 34, 14.040265321731567 s
# 	>Trying H:33
# 		>SAT - ub: 33, 20.598894834518433 s
# 	>Trying H:32
# 		>SAT - ub: 32, 31.57906484603882 s
# Instance[25] solved in 31.579 s, height: 32
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=23 w=33 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 13], [3, 14], [3, 15], [3, 17], [3, 24], [3, 30], [3, 33], [4, 3], [4, 4], [4, 6], [4, 10], [4, 12], [4, 14], [4, 17], [7, 33]]
#
# >Starting Lower Bound: 33
# >Starting Upper Bound: 40
# 	>Trying H:36
# 		>SAT - ub: 36, 4.748214483261108 s
# 	>Trying H:34
# 		>SAT - ub: 34, 9.362104415893555 s
# 	>Trying H:33
# 		>SAT - ub: 33, 18.48201298713684 s
# Instance[26] solved in 18.482 s, height: 33
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=21 w=34 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 13], [3, 14], [3, 21], [3, 22], [3, 25], [3, 34], [4, 4], [4, 5], [4, 11], [4, 14], [12, 34]]
#
# >Starting Lower Bound: 34
# >Starting Upper Bound: 41
# 	>Trying H:37
# 		>SAT - ub: 37, 4.279581546783447 s
# 	>Trying H:35
# 		>SAT - ub: 35, 8.777207612991333 s
# 	>Trying H:34
# 		>SAT - ub: 34, 14.401414632797241 s
# Instance[27] solved in 14.401 s, height: 34
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=22 w=35 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 12], [3, 19], [3, 22], [4, 3], [4, 4], [4, 5], [4, 6], [4, 7], [4, 8], [4, 12], [4, 17], [4, 20], [4, 23], [14, 35]]
#
# >Starting Lower Bound: 35
# >Starting Upper Bound: 43
# 	>Trying H:39
# 		>SAT - ub: 39, 4.785215139389038 s
# 	>Trying H:37
# 		>SAT - ub: 37, 9.712676525115967 s
# 	>Trying H:36
# 		>SAT - ub: 36, 17.0969660282135 s
# 	>Trying H:35
# 		>SAT - ub: 35, 22.497326850891113 s
# Instance[28] solved in 22.497 s, height: 35
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=23 w=36 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 14], [3, 15], [3, 16], [3, 24], [3, 36], [4, 3], [4, 11], [4, 22], [5, 3], [5, 4], [5, 14], [5, 15], [12, 36]]
#
# >Starting Lower Bound: 36
# >Starting Upper Bound: 44
# 	>Trying H:40
# 		>SAT - ub: 40, 5.614977121353149 s
# 	>Trying H:38
# 		>SAT - ub: 38, 12.374554872512817 s
# 	>Trying H:37
# 		>SAT - ub: 37, 17.608720541000366 s
# 	>Trying H:36
# 		>SAT - ub: 36, 33.3780951499939 s
# Instance[29] solved in 33.378 s, height: 36
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=27 w=37 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 11], [3, 12], [3, 13], [3, 14], [3, 17], [3, 18], [3, 21], [4, 3], [4, 4], [4, 5], [4, 6], [4, 10], [4, 22], [4, 24], [5, 3], [5, 4], [5, 6], [5, 10], [5, 14], [12, 37]]
#
# >Starting Lower Bound: 37
# >Starting Upper Bound: 45
# 	>Trying H:41
# 		>SAT - ub: 41, 8.082713603973389 s
# 	>Trying H:39
# 		>SAT - ub: 39, 16.18818712234497 s
# 	>Trying H:38
# 		>SAT - ub: 38, 24.301379919052124 s
# 	>Trying H:37
# 		>SAT - ub: 37, 96.24501466751099 s
# Instance[30] solved in 96.246 s, height: 37
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=19 w=38 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 13], [4, 3], [4, 5], [4, 6], [4, 8], [4, 11], [4, 12], [4, 15], [4, 16], [24, 38]]
#
# >Starting Lower Bound: 38
# >Starting Upper Bound: 44
# 	>Trying H:41
# 		>SAT - ub: 41, 4.4084696769714355 s
# 	>Trying H:39
# 		>SAT - ub: 39, 8.973984956741333 s
# 	>Trying H:38
# 		>SAT - ub: 38, 13.54426622390747 s
# Instance[31] solved in 13.544 s, height: 38
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=29 w=39 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 15], [4, 3], [4, 4], [4, 5], [4, 6], [4, 8], [4, 9], [4, 12], [4, 15], [4, 16], [5, 3], [5, 4], [5, 5], [5, 6], [5, 8], [5, 10], [5, 11], [5, 13], [5, 18], [15, 39]]
#
# >Starting Lower Bound: 39
# >Starting Upper Bound: 44
# 	>Trying H:41
# 		>SAT - ub: 41, 10.696738719940186 s
# 	>Trying H:40
# 		>SAT - ub: 40, 41.34697103500366 s
# 	>Trying H:39
# >Out of time, 308.922 s, best height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=20 w=40 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 12], [3, 16], [3, 40], [4, 4], [4, 14], [4, 22], [5, 3], [5, 4], [5, 8], [5, 12], [5, 13], [22, 40]]
#
# >Starting Lower Bound: 40
# >Starting Upper Bound: 56
# 	>Trying H:48
# 		>SAT - ub: 48, 5.000570058822632 s
# 	>Trying H:44
# 		>SAT - ub: 44, 9.748547315597534 s
# 	>Trying H:42
# 		>SAT - ub: 42, 14.311890363693237 s
# 	>Trying H:41
# 		>SAT - ub: 41, 18.771088123321533 s
# 	>Trying H:40
# 		>SAT - ub: 40, 23.223947048187256 s
# Instance[33] solved in 23.224 s, height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=25 w=15 dim=[[3, 11], [3, 13], [2, 9], [2, 7], [3, 9], [3, 7], [2, 11], [2, 13], [4, 11], [4, 13], [5, 3], [2, 11], [2, 2], [3, 11], [3, 2], [4, 5], [4, 6], [2, 12], [2, 1], [5, 3], [5, 13], [4, 12], [4, 1], [2, 5], [2, 6]]
#
# >Starting Lower Bound: 40
# >Starting Upper Bound: 46
# 	>Trying H:43
# 		>SAT - ub: 43, 5.407870292663574 s
# 	>Trying H:41
# 		>SAT - ub: 41, 10.97541356086731 s
# 	>Trying H:40
# 		>SAT - ub: 40, 21.982824087142944 s
# Instance[34] solved in 21.983 s, height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=25 w=15 dim=[[2, 11], [3, 2], [7, 10], [4, 8], [5, 9], [2, 7], [1, 4], [1, 6], [5, 4], [3, 8], [3, 1], [5, 5], [1, 3], [4, 12], [2, 6], [4, 2], [4, 11], [2, 10], [2, 3], [2, 11], [4, 3], [4, 26], [4, 8], [2, 3], [2, 6]]
#
# >Starting Lower Bound: 40
# >Starting Upper Bound: 44
# 	>Trying H:42
# 		>SAT - ub: 42, 5.425224781036377 s
# 	>Trying H:41
# 		>SAT - ub: 41, 10.868467807769775 s
# 	>Trying H:40
# 		>SAT - ub: 40, 25.468618154525757 s
# Instance[35] solved in 25.469 s, height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=25 w=15 dim=[[7, 12], [7, 7], [1, 7], [1, 5], [2, 3], [2, 6], [2, 7], [2, 5], [1, 3], [1, 6], [6, 12], [6, 9], [2, 12], [2, 7], [3, 10], [1, 4], [1, 5], [3, 16], [3, 5], [2, 4], [2, 5], [3, 10], [3, 9], [3, 16], [3, 5]]
#
# >Starting Lower Bound: 40
# >Starting Upper Bound: 44
# 	>Trying H:42
# 		>SAT - ub: 42, 5.254141569137573 s
# 	>Trying H:41
# 		>SAT - ub: 41, 10.555511236190796 s
# 	>Trying H:40
# 		>SAT - ub: 40, 21.472952842712402 s
# Instance[36] solved in 21.473 s, height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=28 w=30 dim=[[5, 7], [5, 14], [8, 14], [8, 4], [13, 21], [11, 7], [11, 14], [5, 14], [5, 4], [3, 18], [3, 21], [11, 17], [11, 4], [4, 7], [4, 5], [7, 6], [5, 18], [5, 3], [3, 7], [3, 5], [4, 18], [4, 3], [2, 12], [2, 6], [5, 18], [5, 21], [3, 17], [3, 4]]
#
# >Starting Lower Bound: 60
# >Starting Upper Bound: 74
# 	>Trying H:67
# 		>SAT - ub: 67, 11.231030941009521 s
# 	>Trying H:63
# 		>SAT - ub: 63, 22.082095623016357 s
# 	>Trying H:61
# 		>SAT - ub: 61, 51.8193416595459 s
# 	>Trying H:60
# 		>SAT - ub: 60, 308.87856340408325 s
# >Out of time, 308.879 s, best height: 60
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=29 w=30 dim=[[6, 18], [2, 12], [10, 7], [4, 23], [4, 1], [7, 7], [11, 4], [6, 5], [2, 7], [6, 11], [10, 19], [11, 5], [4, 2], [7, 5], [4, 2], [7, 12], [7, 13], [3, 6], [6, 10], [9, 16], [1, 4], [4, 10], [6, 24], [9, 9], [2, 1], [8, 5], [3, 5], [7, 25], [5, 21]]
#
# >Starting Lower Bound: 60
# >Starting Upper Bound: 75
# 	>Trying H:67
# 		>SAT - ub: 67, 12.92715072631836 s
# 	>Trying H:63
# 		>SAT - ub: 63, 25.38435435295105 s
# 	>Trying H:61
# 		>SAT - ub: 61, 38.41829013824463 s
# 	>Trying H:60
# 		>SAT - ub: 60, 237.85844326019287 s
# Instance[38] solved in 237.858 s, height: 60
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=28 w=30 dim=[[9, 24], [9, 8], [9, 11], [9, 17], [4, 24], [4, 8], [1, 6], [1, 5], [4, 17], [3, 6], [3, 5], [12, 5], [12, 13], [14, 14], [2, 14], [2, 2], [8, 3], [8, 9], [12, 14], [12, 2], [6, 3], [6, 9], [2, 5], [2, 13], [3, 18], [3, 14], [3, 16], [3, 12]]
#
# >Starting Lower Bound: 60
# >Starting Upper Bound: 70
# 	>Trying H:65
# 		>SAT - ub: 65, 11.709930658340454 s
# 	>Trying H:62
# 		>SAT - ub: 62, 22.672156810760498 s
# 	>Trying H:61
# 		>SAT - ub: 61, 34.185399293899536 s
# 	>Trying H:60
# 		>SAT - ub: 60, 53.005215883255005 s
# Instance[39] solved in 53.005 s, height: 60
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=73 w=60 dim=[[34, 6], [13, 3], [13, 5], [10, 12], [10, 12], [6, 7], [6, 15], [25, 7], [25, 15], [21, 12], [16, 7], [16, 5], [21, 3], [21, 5], [5, 7], [5, 5], [4, 1], [4, 10], [6, 13], [12, 13], [12, 9], [23, 6], [7, 3], [7, 5], [2, 1], [2, 10], [6, 6], [6, 5], [14, 7], [14, 6], [16, 3], [16, 5], [14, 6], [14, 5], [14, 13], [3, 2], [3, 7], [11, 2], [11, 7], [6, 7], [6, 6], [33, 14], [12, 4], [12, 3], [16, 18], [12, 3], [12, 18], [4, 4], [4, 3], [3, 1], [3, 2], [6, 9], [6, 9], [6, 1], [6, 2], [5, 7], [5, 18], [3, 9], [3, 9], [9, 18], [6, 5], [6, 2], [2, 12], [2, 9], [8, 3], [8, 9], [10, 9], [3, 5], [3, 2], [3, 18], [3, 7], [2, 3], [2, 9]]
#
# >Starting Lower Bound: 90
# >Starting Upper Bound: 104
# 	>Trying H:97
# 		>SAT - ub: 97, 131.61611676216125 s
# 	>Trying H:93
# 		>SAT - ub: 93, 264.5094521045685 s
# 	>Trying H:91
# 	>Trying H:92
# >Out of time, 428.626 s, best height: 93
# ========================================================================================

# %%
from_ins = 1
to_ins   = 40

times = []
for ins in range(from_ins, min(to_ins+1,41)):
    print('========================================================================================')

    # Instance
    instance=utils.loadInstance(f"../instances/ins-{ins}.txt")
    print("Instance:",*["{}={}".format(key,val) for key,val in instance.items()])

    # Solving
    sol,e_time = vlsi_sat(instance)
    
    times.append(round(e_time,3))
    if sol == None:
        print(">Unfeasible.")
    
    if e_time > 300:
        # Write to file
        utils.writeSolution('./outputs2/out-' + str(ins) + '_non_opt.txt', sol)
        
        # Display solution
        utils.display_solution(sol, title= f'Plate {ins}')

        print(f">Out of time, {round(e_time,3)} s, best height: {sol[0][1]}")
    else:
        # Write to file
        utils.writeSolution('./outputs2/out-' + str(ins) + '.txt', sol)

        # Display solution
        utils.display_solution(sol, title= f'Plate {ins}')
        
        # Time
        print(f"Instance[{ins}] solved in {round(e_time,3)} s, height: {sol[0][1]}")
    print('========================================================================================')
    print('\n')

with open('./times_3.txt', 'w+') as f:
    for i in range(from_ins, min(to_ins+1,41)):
            f.write('{}\n'.format(times[i-from_ins]))
# Out:
# ========================================================================================
# Instance: n=4 w=8 dim=[[3, 3], [3, 5], [5, 3], [5, 5]]
#
# >Starting Lower Bound: 8
# >Starting Upper Bound: 9
# 	>Trying H:8
# 		>SAT - ub: 8, 0.04703521728515625 s
# Instance[1] solved in 0.047 s, height: 8
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=5 w=9 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 9]]
#
# >Starting Lower Bound: 9
# >Starting Upper Bound: 10
# 	>Trying H:9
# 		>SAT - ub: 9, 0.06558012962341309 s
# Instance[2] solved in 0.066 s, height: 9
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=6 w=10 dim=[[3, 3], [3, 4], [3, 6], [3, 7], [4, 4], [4, 6]]
#
# >Starting Lower Bound: 10
# >Starting Upper Bound: 14
# 	>Trying H:12
# 		>SAT - ub: 12, 0.11340618133544922 s
# 	>Trying H:11
# 		>SAT - ub: 11, 0.2594015598297119 s
# 	>Trying H:10
# 		>SAT - ub: 10, 0.3574085235595703 s
# Instance[3] solved in 0.357 s, height: 10
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=7 w=11 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [5, 3], [5, 4], [8, 4]]
#
# >Starting Lower Bound: 11
# >Starting Upper Bound: 14
# 	>Trying H:12
# 		>SAT - ub: 12, 0.1650404930114746 s
# 	>Trying H:11
# 		>SAT - ub: 11, 0.31604838371276855 s
# Instance[4] solved in 0.317 s, height: 11
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=8 w=12 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [6, 3]]
#
# >Starting Lower Bound: 12
# >Starting Upper Bound: 14
# 	>Trying H:13
# 		>SAT - ub: 13, 0.21503829956054688 s
# 	>Trying H:12
# 		>SAT - ub: 12, 0.42008471488952637 s
# Instance[5] solved in 0.42 s, height: 12
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=9 w=13 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [4, 3], [4, 4], [7, 6]]
#
# >Starting Lower Bound: 13
# >Starting Upper Bound: 17
# 	>Trying H:15
# 		>SAT - ub: 15, 0.3184988498687744 s
# 	>Trying H:14
# 		>SAT - ub: 14, 0.6242575645446777 s
# 	>Trying H:13
# 		>SAT - ub: 13, 0.9147040843963623 s
# Instance[6] solved in 0.915 s, height: 13
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=9 w=14 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [5, 4], [5, 10]]
#
# >Starting Lower Bound: 14
# >Starting Upper Bound: 19
# 	>Trying H:16
# 		>SAT - ub: 16, 0.31647324562072754 s
# 	>Trying H:15
# 		>SAT - ub: 15, 0.6293787956237793 s
# 	>Trying H:14
# 		>SAT - ub: 14, 0.910325288772583 s
# Instance[7] solved in 0.91 s, height: 14
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=10 w=15 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 12], [3, 15], [6, 3]]
#
# >Starting Lower Bound: 15
# >Starting Upper Bound: 16
# 	>Trying H:15
# 		>SAT - ub: 15, 0.3771555423736572 s
# Instance[8] solved in 0.377 s, height: 15
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=10 w=16 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 10], [3, 12], [4, 7], [7, 9]]
#
# >Starting Lower Bound: 16
# >Starting Upper Bound: 21
# 	>Trying H:18
# 		>SAT - ub: 18, 0.4400348663330078 s
# 	>Trying H:17
# 		>SAT - ub: 17, 0.8501453399658203 s
# 	>Trying H:16
# 		>SAT - ub: 16, 1.244365930557251 s
# Instance[9] solved in 1.244 s, height: 16
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=12 w=17 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [4, 3], [4, 8], [4, 14], [7, 3], [7, 6]]
#
# >Starting Lower Bound: 17
# >Starting Upper Bound: 22
# 	>Trying H:19
# 		>SAT - ub: 19, 0.7074124813079834 s
# 	>Trying H:18
# 		>SAT - ub: 18, 1.3852992057800293 s
# 	>Trying H:17
# 		>SAT - ub: 17, 2.059875249862671 s
# Instance[10] solved in 2.06 s, height: 17
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=16 w=18 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 10], [3, 11], [4, 3], [4, 4], [4, 5], [4, 6], [5, 3], [5, 4], [5, 5], [5, 6]]
#
# >Starting Lower Bound: 18
# >Starting Upper Bound: 22
# 	>Trying H:20
# 		>SAT - ub: 20, 1.4364399909973145 s
# 	>Trying H:19
# 		>SAT - ub: 19, 2.84660267829895 s
# 	>Trying H:18
# 		>SAT - ub: 18, 5.525281190872192 s
# Instance[11] solved in 5.525 s, height: 18
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=14 w=19 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 13], [3, 19], [4, 5], [4, 6], [4, 8]]
#
# >Starting Lower Bound: 19
# >Starting Upper Bound: 24
# 	>Trying H:21
# 		>SAT - ub: 21, 1.0476634502410889 s
# 	>Trying H:20
# 		>SAT - ub: 20, 2.0474390983581543 s
# 	>Trying H:19
# 		>SAT - ub: 19, 3.326050043106079 s
# Instance[12] solved in 3.326 s, height: 19
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=14 w=20 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 17], [4, 3], [4, 9], [4, 11], [4, 17]]
#
# >Starting Lower Bound: 20
# >Starting Upper Bound: 25
# 	>Trying H:22
# 		>SAT - ub: 22, 1.1187660694122314 s
# 	>Trying H:21
# 		>SAT - ub: 21, 2.191983222961426 s
# 	>Trying H:20
# 		>SAT - ub: 20, 3.233917236328125 s
# Instance[13] solved in 3.235 s, height: 20
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=15 w=21 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 14], [3, 18], [4, 4], [4, 6], [4, 11], [5, 6], [5, 15]]
#
# >Starting Lower Bound: 21
# >Starting Upper Bound: 25
# 	>Trying H:23
# 		>SAT - ub: 23, 1.304685115814209 s
# 	>Trying H:22
# 		>SAT - ub: 22, 2.6323933601379395 s
# 	>Trying H:21
# 		>SAT - ub: 21, 3.917184591293335 s
# Instance[14] solved in 3.917 s, height: 21
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=16 w=22 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 13], [3, 14], [3, 22], [4, 3], [4, 19], [6, 4]]
#
# >Starting Lower Bound: 22
# >Starting Upper Bound: 28
# 	>Trying H:25
# 		>SAT - ub: 25, 1.5228440761566162 s
# 	>Trying H:23
# 		>SAT - ub: 23, 2.9098403453826904 s
# 	>Trying H:22
# 		>SAT - ub: 22, 4.401306867599487 s
# Instance[15] solved in 4.401 s, height: 22
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=19 w=23 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 14], [3, 20], [4, 3], [4, 4], [4, 6], [4, 10], [4, 11], [4, 12], [6, 3]]
#
# >Starting Lower Bound: 23
# >Starting Upper Bound: 30
# 	>Trying H:26
# 		>SAT - ub: 26, 2.4592952728271484 s
# 	>Trying H:24
# 		>SAT - ub: 24, 4.955892562866211 s
# 	>Trying H:23
# 		>SAT - ub: 23, 7.402440786361694 s
# Instance[16] solved in 7.402 s, height: 23
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=18 w=24 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 12], [3, 14], [3, 18], [3, 24], [4, 3], [4, 4], [4, 5], [4, 12], [5, 8], [5, 16]]
#
# >Starting Lower Bound: 24
# >Starting Upper Bound: 30
# 	>Trying H:27
# 		>SAT - ub: 27, 2.1712794303894043 s
# 	>Trying H:25
# 		>SAT - ub: 25, 4.200388669967651 s
# 	>Trying H:24
# 		>SAT - ub: 24, 6.4025890827178955 s
# Instance[17] solved in 6.403 s, height: 24
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=19 w=25 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 13], [3, 14], [3, 17], [3, 18], [3, 19], [3, 25], [4, 5], [4, 7], [4, 13], [6, 3]]
#
# >Starting Lower Bound: 25
# >Starting Upper Bound: 31
# 	>Trying H:28
# 		>SAT - ub: 28, 2.4436960220336914 s
# 	>Trying H:26
# 		>SAT - ub: 26, 4.827695369720459 s
# 	>Trying H:25
# 		>SAT - ub: 25, 7.279979944229126 s
# Instance[18] solved in 7.28 s, height: 25
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=22 w=26 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 14], [3, 15], [3, 16], [3, 17], [3, 19], [4, 3], [4, 4], [4, 5], [4, 7], [4, 8], [4, 11], [4, 14]]
#
# >Starting Lower Bound: 26
# >Starting Upper Bound: 33
# 	>Trying H:29
# 		>SAT - ub: 29, 3.649686574935913 s
# 	>Trying H:27
# 		>SAT - ub: 27, 9.27796220779419 s
# 	>Trying H:26
# 		>SAT - ub: 26, 18.71619987487793 s
# Instance[19] solved in 18.716 s, height: 26
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=21 w=27 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 19], [3, 20], [3, 21], [4, 3], [4, 4], [4, 6], [4, 7], [4, 8], [4, 14], [4, 19], [4, 20]]
#
# >Starting Lower Bound: 27
# >Starting Upper Bound: 31
# 	>Trying H:29
# 		>SAT - ub: 29, 3.235438823699951 s
# 	>Trying H:28
# 		>SAT - ub: 28, 6.514481544494629 s
# 	>Trying H:27
# 		>SAT - ub: 27, 13.007200479507446 s
# Instance[20] solved in 13.007 s, height: 27
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=22 w=28 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 16], [3, 17], [3, 21], [3, 23], [4, 3], [4, 4], [4, 5], [4, 8], [4, 13], [4, 23], [5, 6], [5, 9], [5, 13]]
#
# >Starting Lower Bound: 28
# >Starting Upper Bound: 35
# 	>Trying H:31
# 		>SAT - ub: 31, 3.8369433879852295 s
# 	>Trying H:29
# 		>SAT - ub: 29, 8.96261215209961 s
# 	>Trying H:28
# 		>SAT - ub: 28, 13.543904304504395 s
# Instance[21] solved in 13.544 s, height: 28
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=24 w=29 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 15], [3, 18], [3, 20], [4, 3], [4, 4], [4, 5], [4, 6], [4, 7], [4, 9], [4, 15], [4, 18], [4, 20], [5, 4], [5, 8], [5, 17]]
#
# >Starting Lower Bound: 29
# >Starting Upper Bound: 39
# 	>Trying H:34
# 		>SAT - ub: 34, 4.907523155212402 s
# 	>Trying H:31
# 		>SAT - ub: 31, 9.84662127494812 s
# 	>Trying H:30
# 		>SAT - ub: 30, 15.339134693145752 s
# 	>Trying H:29
# 		>SAT - ub: 29, 37.90387988090515 s
# Instance[22] solved in 37.904 s, height: 29
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=20 w=30 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 13], [3, 14], [3, 16], [3, 19], [3, 25], [4, 3], [4, 4], [4, 6], [4, 8], [4, 9], [11, 30]]
#
# >Starting Lower Bound: 30
# >Starting Upper Bound: 37
# 	>Trying H:33
# 		>SAT - ub: 33, 3.329216241836548 s
# 	>Trying H:31
# 		>SAT - ub: 31, 6.534135580062866 s
# 	>Trying H:30
# 		>SAT - ub: 30, 9.676425457000732 s
# Instance[23] solved in 9.676 s, height: 30
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=19 w=31 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 13], [3, 14], [3, 22], [3, 31], [4, 3], [4, 7], [4, 8], [4, 13], [12, 31]]
#
# >Starting Lower Bound: 31
# >Starting Upper Bound: 37
# 	>Trying H:34
# 		>SAT - ub: 34, 3.076481580734253 s
# 	>Trying H:32
# 		>SAT - ub: 32, 6.012580633163452 s
# 	>Trying H:31
# 		>SAT - ub: 31, 10.103898048400879 s
# Instance[24] solved in 10.104 s, height: 31
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=27 w=32 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 13], [3, 14], [3, 15], [3, 18], [3, 22], [3, 23], [3, 24], [3, 25], [3, 27], [4, 3], [4, 4], [4, 5], [4, 6], [4, 7], [4, 10], [4, 11], [4, 18]]
#
# >Starting Lower Bound: 32
# >Starting Upper Bound: 41
# 	>Trying H:36
# 		>SAT - ub: 36, 6.528149366378784 s
# 	>Trying H:34
# 		>SAT - ub: 34, 15.461361408233643 s
# 	>Trying H:33
# 		>SAT - ub: 33, 21.812002658843994 s
# 	>Trying H:32
# 		>SAT - ub: 32, 90.64144825935364 s
# Instance[25] solved in 90.641 s, height: 32
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=23 w=33 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 13], [3, 14], [3, 15], [3, 17], [3, 24], [3, 30], [3, 33], [4, 3], [4, 4], [4, 6], [4, 10], [4, 12], [4, 14], [4, 17], [7, 33]]
#
# >Starting Lower Bound: 33
# >Starting Upper Bound: 40
# 	>Trying H:36
# 		>SAT - ub: 36, 4.616784572601318 s
# 	>Trying H:34
# 		>SAT - ub: 34, 12.36953067779541 s
# 	>Trying H:33
# 		>SAT - ub: 33, 18.008719205856323 s
# Instance[26] solved in 18.009 s, height: 33
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=21 w=34 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 13], [3, 14], [3, 21], [3, 22], [3, 25], [3, 34], [4, 4], [4, 5], [4, 11], [4, 14], [12, 34]]
#
# >Starting Lower Bound: 34
# >Starting Upper Bound: 41
# 	>Trying H:37
# 		>SAT - ub: 37, 4.705709457397461 s
# 	>Trying H:35
# 		>SAT - ub: 35, 11.545244932174683 s
# 	>Trying H:34
# 		>SAT - ub: 34, 16.816380500793457 s
# Instance[27] solved in 16.816 s, height: 34
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=22 w=35 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 12], [3, 19], [3, 22], [4, 3], [4, 4], [4, 5], [4, 6], [4, 7], [4, 8], [4, 12], [4, 17], [4, 20], [4, 23], [14, 35]]
#
# >Starting Lower Bound: 35
# >Starting Upper Bound: 43
# 	>Trying H:39
# 		>SAT - ub: 39, 4.853494167327881 s
# 	>Trying H:37
# 		>SAT - ub: 37, 9.584371089935303 s
# 	>Trying H:36
# 		>SAT - ub: 36, 15.577899932861328 s
# 	>Trying H:35
# 		>SAT - ub: 35, 20.328250885009766 s
# Instance[28] solved in 20.328 s, height: 35
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=23 w=36 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 14], [3, 15], [3, 16], [3, 24], [3, 36], [4, 3], [4, 11], [4, 22], [5, 3], [5, 4], [5, 14], [5, 15], [12, 36]]
#
# >Starting Lower Bound: 36
# >Starting Upper Bound: 44
# 	>Trying H:40
# 		>SAT - ub: 40, 5.290236711502075 s
# 	>Trying H:38
# 		>SAT - ub: 38, 10.745645999908447 s
# 	>Trying H:37
# 		>SAT - ub: 37, 15.710981130599976 s
# 	>Trying H:36
# 		>SAT - ub: 36, 25.88283371925354 s
# Instance[29] solved in 25.883 s, height: 36
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=27 w=37 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 11], [3, 12], [3, 13], [3, 14], [3, 17], [3, 18], [3, 21], [4, 3], [4, 4], [4, 5], [4, 6], [4, 10], [4, 22], [4, 24], [5, 3], [5, 4], [5, 6], [5, 10], [5, 14], [12, 37]]
#
# >Starting Lower Bound: 37
# >Starting Upper Bound: 45
# 	>Trying H:41
# 		>SAT - ub: 41, 7.949490308761597 s
# 	>Trying H:39
# 		>SAT - ub: 39, 15.874255180358887 s
# 	>Trying H:38
# 		>SAT - ub: 38, 23.841347217559814 s
# 	>Trying H:37
# 		>SAT - ub: 37, 169.7776665687561 s
# Instance[30] solved in 169.778 s, height: 37
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=19 w=38 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 13], [4, 3], [4, 5], [4, 6], [4, 8], [4, 11], [4, 12], [4, 15], [4, 16], [24, 38]]
#
# >Starting Lower Bound: 38
# >Starting Upper Bound: 44
# 	>Trying H:41
# 		>SAT - ub: 41, 4.038637161254883 s
# 	>Trying H:39
# 		>SAT - ub: 39, 7.8580851554870605 s
# 	>Trying H:38
# 		>SAT - ub: 38, 11.720862865447998 s
# Instance[31] solved in 11.721 s, height: 38
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=29 w=39 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 15], [4, 3], [4, 4], [4, 5], [4, 6], [4, 8], [4, 9], [4, 12], [4, 15], [4, 16], [5, 3], [5, 4], [5, 5], [5, 6], [5, 8], [5, 10], [5, 11], [5, 13], [5, 18], [15, 39]]
#
# >Starting Lower Bound: 39
# >Starting Upper Bound: 44
# 	>Trying H:41
# 		>SAT - ub: 41, 10.322980642318726 s
# 	>Trying H:40
# 		>SAT - ub: 40, 23.490936279296875 s
# 	>Trying H:39
# >Out of time, 308.569 s, best height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=20 w=40 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 12], [3, 16], [3, 40], [4, 4], [4, 14], [4, 22], [5, 3], [5, 4], [5, 8], [5, 12], [5, 13], [22, 40]]
#
# >Starting Lower Bound: 40
# >Starting Upper Bound: 56
# 	>Trying H:48
# 		>SAT - ub: 48, 4.79573130607605 s
# 	>Trying H:44
# 		>SAT - ub: 44, 9.299447059631348 s
# 	>Trying H:42
# 		>SAT - ub: 42, 13.614262342453003 s
# 	>Trying H:41
# 		>SAT - ub: 41, 17.89573359489441 s
# 	>Trying H:40
# 		>SAT - ub: 40, 22.074915409088135 s
# Instance[33] solved in 22.075 s, height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=25 w=15 dim=[[3, 11], [3, 13], [2, 9], [2, 7], [3, 9], [3, 7], [2, 11], [2, 13], [4, 11], [4, 13], [5, 3], [2, 11], [2, 2], [3, 11], [3, 2], [4, 5], [4, 6], [2, 12], [2, 1], [5, 3], [5, 13], [4, 12], [4, 1], [2, 5], [2, 6]]
#
# >Starting Lower Bound: 40
# >Starting Upper Bound: 46
# 	>Trying H:43
# 		>SAT - ub: 43, 5.199522018432617 s
# 	>Trying H:41
# 		>SAT - ub: 41, 10.431370258331299 s
# 	>Trying H:40
# 		>SAT - ub: 40, 16.44122624397278 s
# Instance[34] solved in 16.441 s, height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=25 w=15 dim=[[2, 11], [3, 2], [7, 10], [4, 8], [5, 9], [2, 7], [1, 4], [1, 6], [5, 4], [3, 8], [3, 1], [5, 5], [1, 3], [4, 12], [2, 6], [4, 2], [4, 11], [2, 10], [2, 3], [2, 11], [4, 3], [4, 26], [4, 8], [2, 3], [2, 6]]
#
# >Starting Lower Bound: 40
# >Starting Upper Bound: 44
# 	>Trying H:42
# 		>SAT - ub: 42, 5.110859632492065 s
# 	>Trying H:41
# 		>SAT - ub: 41, 10.14490294456482 s
# 	>Trying H:40
# 		>SAT - ub: 40, 25.9726824760437 s
# Instance[35] solved in 25.973 s, height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=25 w=15 dim=[[7, 12], [7, 7], [1, 7], [1, 5], [2, 3], [2, 6], [2, 7], [2, 5], [1, 3], [1, 6], [6, 12], [6, 9], [2, 12], [2, 7], [3, 10], [1, 4], [1, 5], [3, 16], [3, 5], [2, 4], [2, 5], [3, 10], [3, 9], [3, 16], [3, 5]]
#
# >Starting Lower Bound: 40
# >Starting Upper Bound: 44
# 	>Trying H:42
# 		>SAT - ub: 42, 5.1298253536224365 s
# 	>Trying H:41
# 		>SAT - ub: 41, 10.223069906234741 s
# 	>Trying H:40
# 		>SAT - ub: 40, 15.386070013046265 s
# Instance[36] solved in 15.386 s, height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=28 w=30 dim=[[5, 7], [5, 14], [8, 14], [8, 4], [13, 21], [11, 7], [11, 14], [5, 14], [5, 4], [3, 18], [3, 21], [11, 17], [11, 4], [4, 7], [4, 5], [7, 6], [5, 18], [5, 3], [3, 7], [3, 5], [4, 18], [4, 3], [2, 12], [2, 6], [5, 18], [5, 21], [3, 17], [3, 4]]
#
# >Starting Lower Bound: 60
# >Starting Upper Bound: 74
# 	>Trying H:67
# 		>SAT - ub: 67, 10.205636739730835 s
# 	>Trying H:63
# 		>SAT - ub: 63, 20.680681705474854 s
# 	>Trying H:61
# 		>SAT - ub: 61, 75.53994584083557 s
# 	>Trying H:60
# 		>SAT - ub: 60, 90.94220113754272 s
# Instance[37] solved in 90.942 s, height: 60
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=29 w=30 dim=[[6, 18], [2, 12], [10, 7], [4, 23], [4, 1], [7, 7], [11, 4], [6, 5], [2, 7], [6, 11], [10, 19], [11, 5], [4, 2], [7, 5], [4, 2], [7, 12], [7, 13], [3, 6], [6, 10], [9, 16], [1, 4], [4, 10], [6, 24], [9, 9], [2, 1], [8, 5], [3, 5], [7, 25], [5, 21]]
#
# >Starting Lower Bound: 60
# >Starting Upper Bound: 75
# 	>Trying H:67
# 		>SAT - ub: 67, 11.901001930236816 s
# 	>Trying H:63
# 		>SAT - ub: 63, 23.18785309791565 s
# 	>Trying H:61
# 		>SAT - ub: 61, 36.03741192817688 s
# 	>Trying H:60
# 		>SAT - ub: 60, 117.09218764305115 s
# Instance[38] solved in 117.092 s, height: 60
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=28 w=30 dim=[[9, 24], [9, 8], [9, 11], [9, 17], [4, 24], [4, 8], [1, 6], [1, 5], [4, 17], [3, 6], [3, 5], [12, 5], [12, 13], [14, 14], [2, 14], [2, 2], [8, 3], [8, 9], [12, 14], [12, 2], [6, 3], [6, 9], [2, 5], [2, 13], [3, 18], [3, 14], [3, 16], [3, 12]]
#
# >Starting Lower Bound: 60
# >Starting Upper Bound: 70
# 	>Trying H:65
# 		>SAT - ub: 65, 10.76436448097229 s
# 	>Trying H:62
# 		>SAT - ub: 62, 21.19831156730652 s
# 	>Trying H:61
# 		>SAT - ub: 61, 31.466007471084595 s
# 	>Trying H:60
# 		>SAT - ub: 60, 125.2692060470581 s
# Instance[39] solved in 125.269 s, height: 60
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=73 w=60 dim=[[34, 6], [13, 3], [13, 5], [10, 12], [10, 12], [6, 7], [6, 15], [25, 7], [25, 15], [21, 12], [16, 7], [16, 5], [21, 3], [21, 5], [5, 7], [5, 5], [4, 1], [4, 10], [6, 13], [12, 13], [12, 9], [23, 6], [7, 3], [7, 5], [2, 1], [2, 10], [6, 6], [6, 5], [14, 7], [14, 6], [16, 3], [16, 5], [14, 6], [14, 5], [14, 13], [3, 2], [3, 7], [11, 2], [11, 7], [6, 7], [6, 6], [33, 14], [12, 4], [12, 3], [16, 18], [12, 3], [12, 18], [4, 4], [4, 3], [3, 1], [3, 2], [6, 9], [6, 9], [6, 1], [6, 2], [5, 7], [5, 18], [3, 9], [3, 9], [9, 18], [6, 5], [6, 2], [2, 12], [2, 9], [8, 3], [8, 9], [10, 9], [3, 5], [3, 2], [3, 18], [3, 7], [2, 3], [2, 9]]
#
# >Starting Lower Bound: 90
# >Starting Upper Bound: 104
# 	>Trying H:97
# 		>SAT - ub: 97, 126.63674402236938 s
# 	>Trying H:93
# 		>SAT - ub: 93, 250.0354118347168 s
# 	>Trying H:91
# 	>Trying H:92
# >Out of time, 418.433 s, best height: 93
# ========================================================================================

# %%
from_ins = 32
to_ins   = 32

times = []
for ins in range(from_ins, min(to_ins+1,41)):
    e_time = 301.0
    while e_time > 300.0:
        print('========================================================================================')

        # Instance
        instance=utils.loadInstance(f"../instances/ins-{ins}.txt")
        print("Instance:",*["{}={}".format(key,val) for key,val in instance.items()])

        # Solving
        sol,e_time = vlsi_sat(instance)

        times.append(round(e_time,3))
        if sol == None:
            print(">Unfeasible.")

        if e_time > 300:
            # Write to file
            utils.writeSolution('./outputs2/out-' + str(ins) + '_non_opt.txt', sol)

            # Display solution
            utils.display_solution(sol, title= f'Plate {ins}')

            print(f">Out of time, {round(e_time,3)} s, best height: {sol[0][1]}")
        else:
            # Write to file
            utils.writeSolution('./outputs2/out-' + str(ins) + '.txt', sol)

            # Display solution
            utils.display_solution(sol, title= f'Plate {ins}')

            # Time
            print(f"Instance[{ins}] solved in {round(e_time,3)} s, height: {sol[0][1]}")
        print('========================================================================================')
        print('\n')
# Out:
# ========================================================================================
# Instance: n=29 w=39 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 15], [4, 3], [4, 4], [4, 5], [4, 6], [4, 8], [4, 9], [4, 12], [4, 15], [4, 16], [5, 3], [5, 4], [5, 5], [5, 6], [5, 8], [5, 10], [5, 11], [5, 13], [5, 18], [15, 39]]
#
# >Starting Lower Bound: 39
# >Starting Upper Bound: 44
# 	>Trying H:41
# 		>SAT - ub: 41, 9.253401517868042 s
# 	>Trying H:40
# 		>SAT - ub: 40, 18.69944953918457 s
# 	>Trying H:39
# >Out of time, 308.943 s, best height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=29 w=39 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 15], [4, 3], [4, 4], [4, 5], [4, 6], [4, 8], [4, 9], [4, 12], [4, 15], [4, 16], [5, 3], [5, 4], [5, 5], [5, 6], [5, 8], [5, 10], [5, 11], [5, 13], [5, 18], [15, 39]]
#
# >Starting Lower Bound: 39
# >Starting Upper Bound: 44
# 	>Trying H:41
# 		>SAT - ub: 41, 11.474272012710571 s
# 	>Trying H:40
# 		>SAT - ub: 40, 26.399230003356934 s
# 	>Trying H:39
# >Out of time, 308.802 s, best height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=29 w=39 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 15], [4, 3], [4, 4], [4, 5], [4, 6], [4, 8], [4, 9], [4, 12], [4, 15], [4, 16], [5, 3], [5, 4], [5, 5], [5, 6], [5, 8], [5, 10], [5, 11], [5, 13], [5, 18], [15, 39]]
#
# >Starting Lower Bound: 39
# >Starting Upper Bound: 44
# 	>Trying H:41
# 		>SAT - ub: 41, 9.766658782958984 s
# 	>Trying H:40
# 		>SAT - ub: 40, 24.01674175262451 s
# 	>Trying H:39
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9584\1674720832.py in <module>
#      13
#      14         # Solving
# ---> 15         sol,e_time = vlsi_sat(instance)
#      16
#      17         times.append(round(e_time,3))
#
# ~\AppData\Local\Temp\ipykernel_9584\3988225894.py in vlsi_sat(instance)
#     149                                 s.add(
#     150                                     *no_overlap(W,H,widths,heights,i,j,False,px,py,lr,ud),
# --> 151                                     *no_overlap(W,H,widths,heights,j,i,False,px,py,lr,ud)
#     152                                 )
#     153                             else:
#
# ~\AppData\Local\Temp\ipykernel_9584\629485270.py in no_overlap(W, H, widths, heights, i, j, flip, px, py, lr, ud)
#      32         for e in range(0,W-dim1):
#      33             cts.append(Or(
# ---> 34                 Not(lr[i][j]),
#      35                 px[i][e],
#      36                 Not(px[j][e+dim1]),
#
# ~\anaconda3\envs\COMB\lib\site-packages\z3\z3.py in Not(a, ctx)
#    1791     else:
#    1792         s = BoolSort(ctx)
# -> 1793         a = s.cast(a)
#    1794         return BoolRef(Z3_mk_not(ctx.ref(), a.as_ast()), ctx)
#    1795
#
# ~\anaconda3\envs\COMB\lib\site-packages\z3\z3.py in cast(self, val)
#    1499                 msg = "True, False or Z3 Boolean expression expected. Received %s of type %s"
#    1500                 _z3_assert(is_expr(val), msg % (val, type(val)))
# -> 1501             if not self.eq(val.sort()):
#    1502                 _z3_assert(self.eq(val.sort()), "Value cannot be converted into a Z3 Boolean value")
#    1503         return val
#
# ~\anaconda3\envs\COMB\lib\site-packages\z3\z3.py in sort(self)
#    1517
#    1518     def sort(self):
# -> 1519         return BoolSortRef(Z3_get_sort(self.ctx_ref(), self.as_ast()), self.ctx)
#    1520
#    1521     def __rmul__(self, other):
#
# ~\anaconda3\envs\COMB\lib\site-packages\z3\z3core.py in Z3_get_sort(a0, a1, _elems)
#    2933
#    2934 def Z3_get_sort(a0, a1, _elems=Elementaries(_lib.Z3_get_sort)):
# -> 2935   r = _elems.f(a0, a1)
#    2936   _elems.Check(a0)
#    2937   return r
#
# KeyboardInterrupt:

# %% [markdown]
# ### Export to .csv

# %%
import csv

print(os.getcwd())
from_ins = 1
to_ins   = 40

times = open("./times_3.txt").readlines()

with open('./vlsi_SAT_3.csv', 'w') as f:
    writer = csv.writer(f, delimiter=';')
    writer.writerow(['Instance', 'Elapsed Time', 'Solution', 'Optimality'])
    for ins in range(from_ins, min(to_ins+1,41)):
        row = []
        if float(times[ins-1]) <= 300.0:
            row = [str(ins), float(times[ins-1]), str(utils.readSolution('./outputs2/out-' + str(ins) + '.txt')), 'OPT']
            writer.writerow(row)
        else:
            row = [str(ins), float(times[ins-1]), str(utils.readSolution('./outputs2/out-' + str(ins) + '_non_opt.txt')), 'NO_OPT']
            writer.writerow(row)

f.close()
# Out:
# C:\Users\Antonio\Documents\UniBO\COMB\cdmo2022\models\SAT

# %% [markdown]
# ### Model with rotations

# %%
def vlsi_sat_rotations(instance):
    
    ''' VARIABLES '''

    n = instance['n']
    W = instance['w']
    widths  = [i[0] for i in instance['dim']]
    heights = [i[1] for i in instance['dim']]
    largest_idx = [w*h for w,h in zip(widths,heights)].index(max([w*h for w,h in\
                                                                        zip(widths,heights)]))   
    tot_area=sum([w*h for w,h in zip(widths,heights)])
    model = None
    
    naiveSolution = utils.computeMostStupidSolution(instance)
    
    if not naiveSolution:
        return None

    lb = int(math.ceil(tot_area/W))
    ub = naiveSolution[0][1]+1
    
    print("\n>Starting Lower Bound:", lb)
    print(">Starting Upper Bound:", ub)
    
    H = int((lb+ub)/2)
    
    s_time = time.time()
    
    while (lb < ub):
        ''' SOLVER WITH 5 MINUTES TIMEOUT'''
        s = Solver()

        s.set("timeout", int(300-(time.time()-s_time))*1000)
        print(f"\t>Trying H:{H}")
        if (time.time() > s_time + 300):
            break
        '''
        ==================================================================
        The variable "f" points wether a component is flipped or not.
        ==================================================================
        '''
        px = [[Bool(f"px{i+1}_{x}") for x in range(W)] for i in range(n)] # x[i][i]: block i has y coordinate <=j
        py = [[Bool(f"py{i+1}_{y}") for y in range(H)] for i in range(n)] # x[i][i]: block i has y coordinate <=j
        lr = [[Bool(f"lr_{i+1}_{j+1}") if j!=i else 0 for j in range(n)] for i in range(n)]
        ud = [[Bool(f"ud_{i+1}_{j+1}") if i!=j else 0 for j in range(n)] for i in range(n)]
        f = [Bool(f"f{i+1}") for i in range(n)] # f[i]: block i is flipped

        # Exactly One constraint
        for i in range(n): 
            '''
            ==================================================================
            Ranges of each component change depending on "f".
            ==================================================================
            '''
            if largest_rectangle(i, largest_idx):
                s.add(Or(
                        And (Not(f[i]), And([px[i][e] for e in range(int((W-widths[i])/2),W)])),
                        And ( f[i],      And([px[i][e] for e in range(int((W-heights[i])/2),W)]))
                    )) # block i starts for sure before position W-wi-> x[i][j]=True for all j > W-wi 

                s.add(Or(
                    And (Not(f[i]), And([py[i][f] for f in range(int((H-heights[i])/2),H)])),
                    And (f[i],      And([py[i][f] for f in range(int((H-widths[i])/2),H)]))
                    ))
                    # same for the y coordinate 
            else:
                s.add(Or(
                        And (Not(f[i]), And([px[i][e] for e in range(W-widths[i],W)])),
                        And ( f[i],      And([px[i][e] for e in range(W-heights[i],W)]))
                    )) # block i starts for sure before position W-wi-> x[i][j]=True for all j > W-wi 

                s.add(Or(
                    And (Not(f[i]), And([py[i][f] for f in range(H-heights[i],H)])),
                    And (f[i],      And([py[i][f] for f in range(H-widths[i],H)]))
                    ))
                    # same for the y coordinate  

            s.add([Or(Not(px[i][e]),px[i][e+1]) for e in range(W-1)]) #x[i][j] implies x[i][j+1]
            s.add([Or(Not(py[i][f]),py[i][f+1]) for f in range(H-1)]) #y[i][j] implies y[i][j+1]

            for j in range(n):
                '''
                ==================================================================
                We must take in account the four possible orientations of
                two components.
                ==================================================================
                '''
                wi,wj,hi,hj=widths[i],widths[j],heights[i],heights[j]    
                cts=[] 
                if i<j:
                    if large_rectangles(widths[i],widths[j],heights[i],heights[j], W, H) == "":
                            if same_rectangles(widths[i],widths[j],heights[i],heights[j]):
                                s.add(Or(lr[i][j],ud[i][j],ud[j][i]))
                                
                                if wi<=W and hi<=H and wj<=W and hj<=H: 
                                    cts.append(And(Not(f[i]),Not(f[j]),
                                                   *no_overlap(W,H,widths,heights,\
                                                                        i,j,False,px,py,lr,ud),
                                                   *no_overlap(W,H,widths,heights,\
                                                                        j,i,False,px,py,False,ud),
                                                  ))
                                if wi<=H and hi<=W and wj<=W and hj<=H:
                                    cts.append(And(f[i],Not(f[j]),
                                                   *no_overlap(W,H,widths,heights,\
                                                                        i,j,True,px,py,lr,ud),
                                                   *no_overlap(W,H,widths,heights,\
                                                                        j,i,False,px,py,False,ud),
                                                  ))
                                if wi<=W and hi<=H and wj<=H and hj<=W:                        
                                    cts.append(And(Not(f[i]),f[j],
                                                   *no_overlap(W,H,widths,heights,\
                                                                        i,j,False,px,py,lr,ud),
                                                   *no_overlap(W,H,widths,heights,\
                                                                        j,i,True,px,py,False,ud),
                                                  ))
                                if wi<=H and hi<=W and wj<=H and hj<=W:                        
                                    cts.append(And(f[i],f[j],
                                                   *no_overlap(W,H,widths,heights,\
                                                                        i,j,True,px,py,lr,ud),
                                                   *no_overlap(W,H,widths,heights,\
                                                                        j,i,True,px,py,False,ud),
                                                  ))
                                s.add(Or(cts))

                                s.add(Or(
                                        Not(ud[i][j]),
                                        lr[j][i]
                                ))
                            else:
                                if not largest_rectangle(j, largest_idx):
                                    s.add(Or(lr[i][j],lr[j][i],ud[i][j],ud[j][i]))     
                                    
                                    if wi<=W and hi<=H and wj<=W and hj<=H: 
                                        cts.append(And(Not(f[i]),Not(f[j]),
                                                       *no_overlap(W,H,widths,heights,\
                                                                            i,j,False,px,py,lr,ud),
                                                       *no_overlap(W,H,widths,heights,\
                                                                            j,i,False,px,py,lr,ud),
                                                      ))
                                    if wi<=H and hi<=W and wj<=W and hj<=H:
                                        cts.append(And(f[i],Not(f[j]),
                                                       *no_overlap(W,H,widths,heights,\
                                                                            i,j,True,px,py,lr,ud),
                                                       *no_overlap(W,H,widths,heights,\
                                                                            j,i,False,px,py,lr,ud),
                                                      ))
                                    if wi<=W and hi<=H and wj<=H and hj<=W:                        
                                        cts.append(And(Not(f[i]),f[j],
                                                       *no_overlap(W,H,widths,heights,\
                                                                            i,j,False,px,py,lr,ud),
                                                       *no_overlap(W,H,widths,heights,\
                                                                            j,i,True,px,py,lr,ud),
                                                      ))
                                    if wi<=H and hi<=W and wj<=H and hj<=W:                        
                                        cts.append(And(f[i],f[j],
                                                       *no_overlap(W,H,widths,heights,\
                                                                            i,j,True,px,py,lr,ud),
                                                       *no_overlap(W,H,widths,heights,\
                                                                            j,i,True,px,py,lr,ud),
                                                      ))
                                    s.add(Or(cts))
                                else:
                                    s.add(Or(lr[j][i],ud[i][j],ud[j][i]))
                                    
                                    if wi<=W and hi<=H and wj<=W and hj<=H: 
                                        cts.append(And(Not(f[i]),Not(f[j]),
                                                       *no_overlap(W,H,widths,heights,\
                                                                            i,j,False,px,py,False,ud),
                                                       *no_overlap(W,H,widths,heights,\
                                                                            j,i,False,px,py,lr,ud),
                                                      ))
                                    if wi<=H and hi<=W and wj<=W and hj<=H:
                                        cts.append(And(f[i],Not(f[j]),
                                                       *no_overlap(W,H,widths,heights,\
                                                                            i,j,True,px,py,False,ud),
                                                       *no_overlap(W,H,widths,heights,\
                                                                            j,i,False,px,py,lr,ud),
                                                      ))
                                    if wi<=W and hi<=H and wj<=H and hj<=W:                        
                                        cts.append(And(Not(f[i]),f[j],
                                                       *no_overlap(W,H,widths,heights,\
                                                                            i,j,False,px,py,False,ud),
                                                       *no_overlap(W,H,widths,heights,\
                                                                            j,i,True,px,py,lr,ud),
                                                      ))
                                    if wi<=H and hi<=W and wj<=H and hj<=W:                        
                                        cts.append(And(f[i],f[j],
                                                       *no_overlap(W,H,widths,heights,\
                                                                            i,j,True,px,py,False,ud),
                                                       *no_overlap(W,H,widths,heights,\
                                                                            j,i,True,px,py,lr,ud),
                                                      ))
                                    s.add(Or(cts))
                                    
                    elif large_rectangles(widths[i],widths[j],heights[i],heights[j], W, H) == "W":
                        s.add(Or(lr[j][i],ud[i][j],ud[j][i]))

                        if wi<=W and hi<=H and wj<=W and hj<=H: 
                            cts.append(And(Not(f[i]),Not(f[j]),
                                           *no_overlap(W,H,widths,heights,\
                                                                i,j,False,px,py,False,ud),
                                           *no_overlap(W,H,widths,heights,\
                                                                j,i,False,px,py,lr,ud),
                                          ))
                        if wi<=H and hi<=W and wj<=W and hj<=H:
                            cts.append(And(f[i],Not(f[j]),
                                           *no_overlap(W,H,widths,heights,\
                                                                i,j,True,px,py,False,ud),
                                           *no_overlap(W,H,widths,heights,\
                                                                j,i,False,px,py,lr,ud),
                                          ))
                        if wi<=W and hi<=H and wj<=H and hj<=W:                        
                            cts.append(And(Not(f[i]),f[j],
                                           *no_overlap(W,H,widths,heights,\
                                                                i,j,False,px,py,False,ud),
                                           *no_overlap(W,H,widths,heights,\
                                                                j,i,True,px,py,lr,ud),
                                          ))
                        if wi<=H and hi<=W and wj<=H and hj<=W:                        
                            cts.append(And(f[i],f[j],
                                           *no_overlap(W,H,widths,heights,\
                                                                i,j,True,px,py,False,ud),
                                           *no_overlap(W,H,widths,heights,\
                                                                j,i,True,px,py,lr,ud),
                                          ))
                        s.add(Or(cts))

                    elif large_rectangles(widths[i],widths[j],heights[i],heights[j], W, H) == "H":
                        if same_rectangles(widths[i],widths[j],heights[i],heights[j]):
                            s.add(lr[i][j])

                            if wi<=W and hi<=H and wj<=W and hj<=H: 
                                cts.append(And(Not(f[i]),Not(f[j]),
                                               *no_overlap(W,H,widths,heights,\
                                                                    i,j,False,px,py,lr,False)
                                              ))
                            if wi<=H and hi<=W and wj<=W and hj<=H:
                                cts.append(And(f[i],Not(f[j]),
                                               *no_overlap(W,H,widths,heights,\
                                                                    i,j,True,px,py,lr,False)
                                              ))
                            if wi<=W and hi<=H and wj<=H and hj<=W:                        
                                cts.append(And(Not(f[i]),f[j],
                                               *no_overlap(W,H,widths,heights,\
                                                                    i,j,False,px,py,lr,False)
                                              ))
                            if wi<=H and hi<=W and wj<=H and hj<=W:                        
                                cts.append(And(f[i],f[j],
                                               *no_overlap(W,H,widths,heights,\
                                                                    i,j,True,px,py,lr,False)
                                              ))
                            s.add(Or(cts))

                            s.add(Or(
                                    Not(ud[i][j]),
                                    lr[j][i]
                            ))  
                        else:                            
                            s.add(Or(lr[i][j],lr[j][i]))

                            if wi<=W and hi<=H and wj<=W and hj<=H: 
                                cts.append(And(Not(f[i]),Not(f[j]),
                                               *no_overlap(W,H,widths,heights,\
                                                                    i,j,False,px,py,lr,False),
                                               *no_overlap(W,H,widths,heights,\
                                                                    j,i,False,px,py,lr,False),
                                              ))
                            if wi<=H and hi<=W and wj<=W and hj<=H:
                                cts.append(And(f[i],Not(f[j]),
                                               *no_overlap(W,H,widths,heights,\
                                                                    i,j,True,px,py,lr,False),
                                               *no_overlap(W,H,widths,heights,\
                                                                    j,i,False,px,py,lr,False),
                                              ))
                            if wi<=W and hi<=H and wj<=H and hj<=W:                        
                                cts.append(And(Not(f[i]),f[j],
                                               *no_overlap(W,H,widths,heights,\
                                                                    i,j,False,px,py,lr,False),
                                               *no_overlap(W,H,widths,heights,\
                                                                    j,i,True,px,py,lr,False),
                                              ))
                            if wi<=H and hi<=W and wj<=H and hj<=W:                        
                                cts.append(And(f[i],f[j],
                                               *no_overlap(W,H,widths,heights,\
                                                                    i,j,True,px,py,lr,False),
                                               *no_overlap(W,H,widths,heights,\
                                                                    j,i,True,px,py,lr,False),
                                              ))
                            s.add(Or(cts))

        if s.check() == sat:
            ub = H
            model = s.model()            
            
            print(f'\t\t>SAT - ub: {ub}, {time.time() - s_time} s')
            
        else:
            lb = H + 1
            if (time.time() - s_time <= 300):
                print(f'\t\t>UNSAT - lb: {lb}, {time.time() - s_time} s')

            
        H =  int((lb+ub)/2)
        
        '''
        ==================================================================
        'Bisection Method':
            while lb < ub
                o := (lb + ub)/2;
                resubt := Ψ ∪ {ph_o};
                if resubt is SAT
                    then ub := o;
                    else lb := o + 1;
            end while
        ==================================================================
        '''
    
    e_time = time.time() - s_time

    
    if model == None:
        return None, 0.0
    elif e_time > 300:
        variables = { str(d):model.evaluate(model[d]) for d in model }
        cx,cy,widths,heights = getCoords(variables, W, ub, n, widths, heights, True)

        sol = [[W,ub]]+[[widths[i],heights[i],cx[i]+1,cy[i]+1]\
                    for i in range(min(len(cx),len(cy),len(widths),len(heights)))]
        
        return sol, e_time
    else:
        variables = { str(d):model.evaluate(model[d]) for d in model }
                
        cx,cy,widths,heights = getCoords(variables, W, H, n, widths, heights, True)
        sol=[[W,H]]+[[widths[i],heights[i],cx[i]+1,cy[i]+1] for i in range(n)]
        
        return sol, e_time

# %% [markdown]
# ### Execution

# %%
from_ins = 1
to_ins   = 40

times = []
for ins in range(from_ins, min(to_ins+1,41)):
    print('========================================================================================')

    # Instance
    instance=utils.loadInstance(f"../instances/ins-{ins}.txt")
    print("Instance:",*["{}={}".format(key,val) for key,val in instance.items()])

    # Solving
    sol,e_time = vlsi_sat_rotations(instance)
    
    times.append(round(e_time,3))
    if sol == None:
        print(">Unfeasible.")
    
    if e_time > 300:
        # Write to file
        utils.writeSolution('./outputs_rot/out-' + str(ins) + '_non_opt.txt', sol)
        
        # Display solution
        utils.display_solution(sol, title= f'Plate {ins}')

        print(f">Out of time, {round(e_time,3)} s, best height: {sol[0][1]}")
    else:
        # Write to file
        utils.writeSolution('./outputs_rot/out-' + str(ins) + '.txt', sol)

        # Display solution
        utils.display_solution(sol, title= f'Plate {ins}')
        
        # Time
        print(f"Instance[{ins}] solved in {round(e_time,3)} s, height: {sol[0][1]}")
    print('========================================================================================')
    print('\n')

with open('./times_2_r.txt', 'w+') as f:
    for i in range(from_ins, min(to_ins+1,41)):
            f.write('{}\n'.format(times[i-from_ins]))
# Out:
# ========================================================================================
# Instance: n=4 w=8 dim=[[3, 3], [3, 5], [5, 3], [5, 5]]
#
# >Starting Lower Bound: 8
# >Starting Upper Bound: 9
# 	>Trying H:8
# 		>SAT - ub: 8, 0.11368513107299805 s
# Instance[1] solved in 0.114 s, height: 8
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=5 w=9 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 9]]
#
# >Starting Lower Bound: 9
# >Starting Upper Bound: 10
# 	>Trying H:9
# 		>SAT - ub: 9, 0.17235207557678223 s
# Instance[2] solved in 0.172 s, height: 9
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=6 w=10 dim=[[3, 3], [3, 4], [3, 6], [3, 7], [4, 4], [4, 6]]
#
# >Starting Lower Bound: 10
# >Starting Upper Bound: 14
# 	>Trying H:12
# 		>SAT - ub: 12, 0.37770962715148926 s
# 	>Trying H:11
# 		>SAT - ub: 11, 0.7379848957061768 s
# 	>Trying H:10
# 		>SAT - ub: 10, 1.0285460948944092 s
# Instance[3] solved in 1.029 s, height: 10
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=7 w=11 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [5, 3], [5, 4], [8, 4]]
#
# >Starting Lower Bound: 11
# >Starting Upper Bound: 14
# 	>Trying H:12
# 		>SAT - ub: 12, 0.5691299438476562 s
# 	>Trying H:11
# 		>SAT - ub: 11, 1.0964813232421875 s
# Instance[4] solved in 1.096 s, height: 11
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=8 w=12 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [6, 3]]
#
# >Starting Lower Bound: 12
# >Starting Upper Bound: 14
# 	>Trying H:13
# 		>SAT - ub: 13, 0.7801103591918945 s
# 	>Trying H:12
# 		>SAT - ub: 12, 1.4723625183105469 s
# Instance[5] solved in 1.472 s, height: 12
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=9 w=13 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [4, 3], [4, 4], [7, 6]]
#
# >Starting Lower Bound: 13
# >Starting Upper Bound: 17
# 	>Trying H:15
# 		>SAT - ub: 15, 1.2613933086395264 s
# 	>Trying H:14
# 		>SAT - ub: 14, 2.446472406387329 s
# 	>Trying H:13
# 		>SAT - ub: 13, 3.567549467086792 s
# Instance[6] solved in 3.568 s, height: 13
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=9 w=14 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [5, 4], [5, 10]]
#
# >Starting Lower Bound: 14
# >Starting Upper Bound: 19
# 	>Trying H:16
# 		>SAT - ub: 16, 1.1975243091583252 s
# 	>Trying H:15
# 		>SAT - ub: 15, 2.347620964050293 s
# 	>Trying H:14
# 		>SAT - ub: 14, 3.4436187744140625 s
# Instance[7] solved in 3.444 s, height: 14
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=10 w=15 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 12], [3, 15], [6, 3]]
#
# >Starting Lower Bound: 15
# >Starting Upper Bound: 16
# 	>Trying H:15
# 		>SAT - ub: 15, 1.3503899574279785 s
# Instance[8] solved in 1.35 s, height: 15
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=10 w=16 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 10], [3, 12], [4, 7], [7, 9]]
#
# >Starting Lower Bound: 16
# >Starting Upper Bound: 21
# 	>Trying H:18
# 		>SAT - ub: 18, 1.7204608917236328 s
# 	>Trying H:17
# 		>SAT - ub: 17, 3.3097314834594727 s
# 	>Trying H:16
# 		>SAT - ub: 16, 4.819003582000732 s
# Instance[9] solved in 4.819 s, height: 16
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=12 w=17 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [4, 3], [4, 8], [4, 14], [7, 3], [7, 6]]
#
# >Starting Lower Bound: 17
# >Starting Upper Bound: 22
# 	>Trying H:19
# 		>SAT - ub: 19, 2.888847589492798 s
# 	>Trying H:18
# 		>SAT - ub: 18, 5.536885499954224 s
# 	>Trying H:17
# 		>SAT - ub: 17, 8.300222635269165 s
# Instance[10] solved in 8.3 s, height: 17
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=16 w=18 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 10], [3, 11], [4, 3], [4, 4], [4, 5], [4, 6], [5, 3], [5, 4], [5, 5], [5, 6]]
#
# >Starting Lower Bound: 18
# >Starting Upper Bound: 22
# 	>Trying H:20
# 		>SAT - ub: 20, 6.1049675941467285 s
# 	>Trying H:19
# 		>SAT - ub: 19, 12.081372261047363 s
# 	>Trying H:18
# 		>SAT - ub: 18, 23.98161244392395 s
# Instance[11] solved in 23.983 s, height: 18
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=14 w=19 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 13], [3, 19], [4, 5], [4, 6], [4, 8]]
#
# >Starting Lower Bound: 19
# >Starting Upper Bound: 24
# 	>Trying H:21
# 		>SAT - ub: 21, 4.306037425994873 s
# 	>Trying H:20
# 		>SAT - ub: 20, 8.547439575195312 s
# 	>Trying H:19
# 		>SAT - ub: 19, 12.94414234161377 s
# Instance[12] solved in 12.945 s, height: 19
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=14 w=20 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 17], [4, 3], [4, 9], [4, 11], [4, 17]]
#
# >Starting Lower Bound: 20
# >Starting Upper Bound: 25
# 	>Trying H:22
# 		>SAT - ub: 22, 4.367707967758179 s
# 	>Trying H:21
# 		>SAT - ub: 21, 8.692437887191772 s
# 	>Trying H:20
# 		>SAT - ub: 20, 12.514779329299927 s
# Instance[13] solved in 12.515 s, height: 20
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=15 w=21 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 14], [3, 18], [4, 4], [4, 6], [4, 11], [5, 6], [5, 15]]
#
# >Starting Lower Bound: 21
# >Starting Upper Bound: 25
# 	>Trying H:23
# 		>SAT - ub: 23, 5.2400288581848145 s
# 	>Trying H:22
# 		>SAT - ub: 22, 10.57297396659851 s
# 	>Trying H:21
# 		>SAT - ub: 21, 16.11409831047058 s
# Instance[14] solved in 16.114 s, height: 21
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=16 w=22 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 13], [3, 14], [3, 22], [4, 3], [4, 19], [6, 4]]
#
# >Starting Lower Bound: 22
# >Starting Upper Bound: 28
# 	>Trying H:25
# 		>SAT - ub: 25, 6.345464706420898 s
# 	>Trying H:23
# 		>SAT - ub: 23, 12.23396348953247 s
# 	>Trying H:22
# 		>SAT - ub: 22, 18.149905681610107 s
# Instance[15] solved in 18.15 s, height: 22
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=19 w=23 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 14], [3, 20], [4, 3], [4, 4], [4, 6], [4, 10], [4, 11], [4, 12], [6, 3]]
#
# >Starting Lower Bound: 23
# >Starting Upper Bound: 30
# 	>Trying H:26
# 		>SAT - ub: 26, 10.26495909690857 s
# 	>Trying H:24
# 		>SAT - ub: 24, 20.54308319091797 s
# 	>Trying H:23
# 		>SAT - ub: 23, 63.16611433029175 s
# Instance[16] solved in 63.166 s, height: 23
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=18 w=24 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 12], [3, 14], [3, 18], [3, 24], [4, 3], [4, 4], [4, 5], [4, 12], [5, 8], [5, 16]]
#
# >Starting Lower Bound: 24
# >Starting Upper Bound: 30
# 	>Trying H:27
# 		>SAT - ub: 27, 9.52072548866272 s
# 	>Trying H:25
# 		>SAT - ub: 25, 18.714216232299805 s
# 	>Trying H:24
# 		>SAT - ub: 24, 28.924853086471558 s
# Instance[17] solved in 28.925 s, height: 24
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=19 w=25 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 13], [3, 14], [3, 17], [3, 18], [3, 19], [3, 25], [4, 5], [4, 7], [4, 13], [6, 3]]
#
# >Starting Lower Bound: 25
# >Starting Upper Bound: 31
# 	>Trying H:28
# 		>SAT - ub: 28, 10.843775033950806 s
# 	>Trying H:26
# 		>SAT - ub: 26, 22.358442306518555 s
# 	>Trying H:25
# 		>SAT - ub: 25, 44.24595546722412 s
# Instance[18] solved in 44.246 s, height: 25
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=22 w=26 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 14], [3, 15], [3, 16], [3, 17], [3, 19], [4, 3], [4, 4], [4, 5], [4, 7], [4, 8], [4, 11], [4, 14]]
#
# >Starting Lower Bound: 26
# >Starting Upper Bound: 33
# 	>Trying H:29
# 		>SAT - ub: 29, 16.417272806167603 s
# 	>Trying H:27
# 		>SAT - ub: 27, 32.12960720062256 s
# 	>Trying H:26
# 		>SAT - ub: 26, 54.031588315963745 s
# Instance[19] solved in 54.032 s, height: 26
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=21 w=27 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 19], [3, 20], [3, 21], [4, 3], [4, 4], [4, 6], [4, 7], [4, 8], [4, 14], [4, 19], [4, 20]]
#
# >Starting Lower Bound: 27
# >Starting Upper Bound: 31
# 	>Trying H:29
# 		>SAT - ub: 29, 13.902190446853638 s
# 	>Trying H:28
# 		>SAT - ub: 28, 28.271356344223022 s
# 	>Trying H:27
# 		>SAT - ub: 27, 44.674206495285034 s
# Instance[20] solved in 44.674 s, height: 27
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=22 w=28 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 16], [3, 17], [3, 21], [3, 23], [4, 3], [4, 4], [4, 5], [4, 8], [4, 13], [4, 23], [5, 6], [5, 9], [5, 13]]
#
# >Starting Lower Bound: 28
# >Starting Upper Bound: 35
# 	>Trying H:31
# 		>SAT - ub: 31, 17.350915670394897 s
# 	>Trying H:29
# 		>SAT - ub: 29, 34.6149525642395 s
# 	>Trying H:28
# 		>SAT - ub: 28, 95.19702386856079 s
# Instance[21] solved in 95.197 s, height: 28
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=24 w=29 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 15], [3, 18], [3, 20], [4, 3], [4, 4], [4, 5], [4, 6], [4, 7], [4, 9], [4, 15], [4, 18], [4, 20], [5, 4], [5, 8], [5, 17]]
#
# >Starting Lower Bound: 29
# >Starting Upper Bound: 39
# 	>Trying H:34
# 		>SAT - ub: 34, 22.52024507522583 s
# 	>Trying H:31
# 		>SAT - ub: 31, 42.97669196128845 s
# 	>Trying H:30
# 		>SAT - ub: 30, 63.87690234184265 s
# 	>Trying H:29
# 		>SAT - ub: 29, 266.67424392700195 s
# Instance[22] solved in 266.674 s, height: 29
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=20 w=30 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 13], [3, 14], [3, 16], [3, 19], [3, 25], [4, 3], [4, 4], [4, 6], [4, 8], [4, 9], [11, 30]]
#
# >Starting Lower Bound: 30
# >Starting Upper Bound: 37
# 	>Trying H:33
# 		>SAT - ub: 33, 14.743667602539062 s
# 	>Trying H:31
# 		>SAT - ub: 31, 29.11070227622986 s
# 	>Trying H:30
# 		>SAT - ub: 30, 68.57196307182312 s
# Instance[23] solved in 68.572 s, height: 30
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=19 w=31 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 13], [3, 14], [3, 22], [3, 31], [4, 3], [4, 7], [4, 8], [4, 13], [12, 31]]
#
# >Starting Lower Bound: 31
# >Starting Upper Bound: 37
# 	>Trying H:34
# 		>SAT - ub: 34, 12.979048728942871 s
# 	>Trying H:32
# 		>SAT - ub: 32, 25.736252784729004 s
# 	>Trying H:31
# 		>SAT - ub: 31, 67.61805772781372 s
# Instance[24] solved in 67.618 s, height: 31
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=27 w=32 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 13], [3, 14], [3, 15], [3, 18], [3, 22], [3, 23], [3, 24], [3, 25], [3, 27], [4, 3], [4, 4], [4, 5], [4, 6], [4, 7], [4, 10], [4, 11], [4, 18]]
#
# >Starting Lower Bound: 32
# >Starting Upper Bound: 41
# 	>Trying H:36
# 		>SAT - ub: 36, 29.926069498062134 s
# 	>Trying H:34
# 		>SAT - ub: 34, 58.372981548309326 s
# 	>Trying H:33
# 		>SAT - ub: 33, 86.22825980186462 s
# 	>Trying H:32
# 		>SAT - ub: 32, 257.23457169532776 s
# Instance[25] solved in 257.235 s, height: 32
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=23 w=33 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 13], [3, 14], [3, 15], [3, 17], [3, 24], [3, 30], [3, 33], [4, 3], [4, 4], [4, 6], [4, 10], [4, 12], [4, 14], [4, 17], [7, 33]]
#
# >Starting Lower Bound: 33
# >Starting Upper Bound: 40
# 	>Trying H:36
# 		>SAT - ub: 36, 20.72574543952942 s
# 	>Trying H:34
# 		>SAT - ub: 34, 40.63896036148071 s
# 	>Trying H:33
# 		>SAT - ub: 33, 151.40610814094543 s
# Instance[26] solved in 151.406 s, height: 33
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=21 w=34 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 13], [3, 14], [3, 21], [3, 22], [3, 25], [3, 34], [4, 4], [4, 5], [4, 11], [4, 14], [12, 34]]
#
# >Starting Lower Bound: 34
# >Starting Upper Bound: 41
# 	>Trying H:37
# 		>SAT - ub: 37, 18.17004084587097 s
# 	>Trying H:35
# 		>SAT - ub: 35, 35.59643006324768 s
# 	>Trying H:34
# 		>SAT - ub: 34, 55.9017813205719 s
# Instance[27] solved in 55.903 s, height: 34
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=22 w=35 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 12], [3, 19], [3, 22], [4, 3], [4, 4], [4, 5], [4, 6], [4, 7], [4, 8], [4, 12], [4, 17], [4, 20], [4, 23], [14, 35]]
#
# >Starting Lower Bound: 35
# >Starting Upper Bound: 43
# 	>Trying H:39
# 		>SAT - ub: 39, 22.191706895828247 s
# 	>Trying H:37
# 		>SAT - ub: 37, 43.913676261901855 s
# 	>Trying H:36
# 		>SAT - ub: 36, 66.0008635520935 s
# 	>Trying H:35
# 		>SAT - ub: 35, 133.793701171875 s
# Instance[28] solved in 133.794 s, height: 35
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=23 w=36 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 12], [3, 14], [3, 15], [3, 16], [3, 24], [3, 36], [4, 3], [4, 11], [4, 22], [5, 3], [5, 4], [5, 14], [5, 15], [12, 36]]
#
# >Starting Lower Bound: 36
# >Starting Upper Bound: 44
# 	>Trying H:40
# 		>SAT - ub: 40, 23.287662744522095 s
# 	>Trying H:38
# 		>SAT - ub: 38, 45.10714840888977 s
# 	>Trying H:37
# 		>SAT - ub: 37, 69.14754796028137 s
# 	>Trying H:36
# 		>SAT - ub: 36, 97.44305109977722 s
# Instance[29] solved in 97.443 s, height: 36
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=27 w=37 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 11], [3, 12], [3, 13], [3, 14], [3, 17], [3, 18], [3, 21], [4, 3], [4, 4], [4, 5], [4, 6], [4, 10], [4, 22], [4, 24], [5, 3], [5, 4], [5, 6], [5, 10], [5, 14], [12, 37]]
#
# >Starting Lower Bound: 37
# >Starting Upper Bound: 45
# 	>Trying H:41
# 		>SAT - ub: 41, 35.75826907157898 s
# 	>Trying H:39
# 		>SAT - ub: 39, 73.91466331481934 s
# 	>Trying H:38
# 		>SAT - ub: 38, 111.81933927536011 s
# 	>Trying H:37
# >Out of time, 331.445 s, best height: 38
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=19 w=38 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 13], [4, 3], [4, 5], [4, 6], [4, 8], [4, 11], [4, 12], [4, 15], [4, 16], [24, 38]]
#
# >Starting Lower Bound: 38
# >Starting Upper Bound: 44
# 	>Trying H:41
# 		>SAT - ub: 41, 16.95385980606079 s
# 	>Trying H:39
# 		>SAT - ub: 39, 33.796714305877686 s
# 	>Trying H:38
# 		>SAT - ub: 38, 55.66507363319397 s
# Instance[31] solved in 55.665 s, height: 38
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=29 w=39 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 11], [3, 15], [4, 3], [4, 4], [4, 5], [4, 6], [4, 8], [4, 9], [4, 12], [4, 15], [4, 16], [5, 3], [5, 4], [5, 5], [5, 6], [5, 8], [5, 10], [5, 11], [5, 13], [5, 18], [15, 39]]
#
# >Starting Lower Bound: 39
# >Starting Upper Bound: 44
# 	>Trying H:41
# 		>SAT - ub: 41, 44.02996754646301 s
# 	>Trying H:40
# 		>SAT - ub: 40, 217.48793411254883 s
# 	>Trying H:39
# >Out of time, 337.747 s, best height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=20 w=40 dim=[[3, 3], [3, 4], [3, 5], [3, 6], [3, 7], [3, 8], [3, 9], [3, 10], [3, 12], [3, 16], [3, 40], [4, 4], [4, 14], [4, 22], [5, 3], [5, 4], [5, 8], [5, 12], [5, 13], [22, 40]]
#
# >Starting Lower Bound: 40
# >Starting Upper Bound: 56
# 	>Trying H:48
# 		>SAT - ub: 48, 19.94864058494568 s
# 	>Trying H:44
# 		>SAT - ub: 44, 39.30360269546509 s
# 	>Trying H:42
# 		>SAT - ub: 42, 57.99280667304993 s
# 	>Trying H:41
# 		>SAT - ub: 41, 79.90214586257935 s
# 	>Trying H:40
# 		>SAT - ub: 40, 114.2381227016449 s
# Instance[33] solved in 114.238 s, height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=25 w=15 dim=[[3, 11], [3, 13], [2, 9], [2, 7], [3, 9], [3, 7], [2, 11], [2, 13], [4, 11], [4, 13], [5, 3], [2, 11], [2, 2], [3, 11], [3, 2], [4, 5], [4, 6], [2, 12], [2, 1], [5, 3], [5, 13], [4, 12], [4, 1], [2, 5], [2, 6]]
#
# >Starting Lower Bound: 40
# >Starting Upper Bound: 46
# 	>Trying H:43
# 		>SAT - ub: 43, 21.760239362716675 s
# 	>Trying H:41
# 		>SAT - ub: 41, 43.70590424537659 s
# 	>Trying H:40
# 		>SAT - ub: 40, 161.25972771644592 s
# Instance[34] solved in 161.26 s, height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=25 w=15 dim=[[2, 11], [3, 2], [7, 10], [4, 8], [5, 9], [2, 7], [1, 4], [1, 6], [5, 4], [3, 8], [3, 1], [5, 5], [1, 3], [4, 12], [2, 6], [4, 2], [4, 11], [2, 10], [2, 3], [2, 11], [4, 3], [4, 26], [4, 8], [2, 3], [2, 6]]
#
# >Starting Lower Bound: 40
# >Starting Upper Bound: 44
# 	>Trying H:42
# 		>SAT - ub: 42, 22.232162475585938 s
# 	>Trying H:41
# 		>SAT - ub: 41, 43.66467213630676 s
# 	>Trying H:40
# 		>SAT - ub: 40, 67.51072192192078 s
# Instance[35] solved in 67.511 s, height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=25 w=15 dim=[[7, 12], [7, 7], [1, 7], [1, 5], [2, 3], [2, 6], [2, 7], [2, 5], [1, 3], [1, 6], [6, 12], [6, 9], [2, 12], [2, 7], [3, 10], [1, 4], [1, 5], [3, 16], [3, 5], [2, 4], [2, 5], [3, 10], [3, 9], [3, 16], [3, 5]]
#
# >Starting Lower Bound: 40
# >Starting Upper Bound: 44
# 	>Trying H:42
# 		>SAT - ub: 42, 21.128289222717285 s
# 	>Trying H:41
# 		>SAT - ub: 41, 41.96525192260742 s
# 	>Trying H:40
# 		>SAT - ub: 40, 64.07681679725647 s
# Instance[36] solved in 64.077 s, height: 40
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=28 w=30 dim=[[5, 7], [5, 14], [8, 14], [8, 4], [13, 21], [11, 7], [11, 14], [5, 14], [5, 4], [3, 18], [3, 21], [11, 17], [11, 4], [4, 7], [4, 5], [7, 6], [5, 18], [5, 3], [3, 7], [3, 5], [4, 18], [4, 3], [2, 12], [2, 6], [5, 18], [5, 21], [3, 17], [3, 4]]
#
# >Starting Lower Bound: 60
# >Starting Upper Bound: 74
# 	>Trying H:67
# 		>SAT - ub: 67, 48.29136061668396 s
# 	>Trying H:63
# 		>SAT - ub: 63, 93.52696967124939 s
# 	>Trying H:61
# 		>SAT - ub: 61, 140.23260283470154 s
# 	>Trying H:60
# >Out of time, 340.173 s, best height: 61
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=29 w=30 dim=[[6, 18], [2, 12], [10, 7], [4, 23], [4, 1], [7, 7], [11, 4], [6, 5], [2, 7], [6, 11], [10, 19], [11, 5], [4, 2], [7, 5], [4, 2], [7, 12], [7, 13], [3, 6], [6, 10], [9, 16], [1, 4], [4, 10], [6, 24], [9, 9], [2, 1], [8, 5], [3, 5], [7, 25], [5, 21]]
#
# >Starting Lower Bound: 60
# >Starting Upper Bound: 75
# 	>Trying H:67
# 		>SAT - ub: 67, 51.36277461051941 s
# 	>Trying H:63
# 		>SAT - ub: 63, 102.4165391921997 s
# 	>Trying H:61
# 		>SAT - ub: 61, 164.8313844203949 s
# 	>Trying H:60
# >Out of time, 344.483 s, best height: 61
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=28 w=30 dim=[[9, 24], [9, 8], [9, 11], [9, 17], [4, 24], [4, 8], [1, 6], [1, 5], [4, 17], [3, 6], [3, 5], [12, 5], [12, 13], [14, 14], [2, 14], [2, 2], [8, 3], [8, 9], [12, 14], [12, 2], [6, 3], [6, 9], [2, 5], [2, 13], [3, 18], [3, 14], [3, 16], [3, 12]]
#
# >Starting Lower Bound: 60
# >Starting Upper Bound: 70
# 	>Trying H:65
# 		>SAT - ub: 65, 47.692400217056274 s
# 	>Trying H:62
# 		>SAT - ub: 62, 92.78033590316772 s
# 	>Trying H:61
# 		>SAT - ub: 61, 137.8462872505188 s
# 	>Trying H:60
# >Out of time, 341.229 s, best height: 61
# ========================================================================================
#
#
# ========================================================================================
# Instance: n=73 w=60 dim=[[34, 6], [13, 3], [13, 5], [10, 12], [10, 12], [6, 7], [6, 15], [25, 7], [25, 15], [21, 12], [16, 7], [16, 5], [21, 3], [21, 5], [5, 7], [5, 5], [4, 1], [4, 10], [6, 13], [12, 13], [12, 9], [23, 6], [7, 3], [7, 5], [2, 1], [2, 10], [6, 6], [6, 5], [14, 7], [14, 6], [16, 3], [16, 5], [14, 6], [14, 5], [14, 13], [3, 2], [3, 7], [11, 2], [11, 7], [6, 7], [6, 6], [33, 14], [12, 4], [12, 3], [16, 18], [12, 3], [12, 18], [4, 4], [4, 3], [3, 1], [3, 2], [6, 9], [6, 9], [6, 1], [6, 2], [5, 7], [5, 18], [3, 9], [3, 9], [9, 18], [6, 5], [6, 2], [2, 12], [2, 9], [8, 3], [8, 9], [10, 9], [3, 5], [3, 2], [3, 18], [3, 7], [2, 3], [2, 9]]
#
# >Starting Lower Bound: 90
# >Starting Upper Bound: 104
# 	>Trying H:97
# 		>SAT - ub: 97, 592.8425495624542 s
# 	>Trying H:93
# >Out of time, 593.292 s, best height: 97
# ========================================================================================

# %% [markdown]
# ### Export to .csv

# %%
import csv

from_ins = 1
to_ins   = 40

times_r = open("./times_2_r.txt").readlines()

with open('./vlsi_SAT_2_r.csv', 'w') as f:
    writer = csv.writer(f, delimiter=';')
    writer.writerow(['Instance', 'Elapsed Time', 'Solution', 'Optimality'])
    for ins in range(from_ins, min(to_ins+1,41)):
        row = []
        if float(times[ins-1]) <= 300.0:
            row = [str(ins), float(times[ins-1]), str(utils.readSolution('./outputs/out-' + str(ins) + '.txt')), 'OPT']
            writer.writerow(row)
        else:
            row = [str(ins), float(times[ins-1]), str(utils.readSolution('./outputs/out-' + str(ins) + '.txt')), 'NO_OPT']
            writer.writerow(row)

f.close()
